# %% [markdown]
# # 训练 RNN 语言模型
#
# 1. 词语的embedding
# 2. embedding空间和state空间
# 3. 连续词语之间的关联

# %%
import numpy as np
import tensorflow as tf
from model import CharRNNLM
from utils import VocabularyLoader, batche2string

TF_VERSION = int(tf.__version__.split('.')[1])

# %%
class BatchGenerator(object):
    
    def __init__(self, tensor_in, tensor_out, batch_size, seq_length):
        """初始化batch产生器
        Input:
            batch_size: 每一个mini-batch里面有多少样本。
            seq_length: 每一个样本的长度，和batch_size一起决定了每个minibatch的数据量。
        """
        self.batch_size = batch_size
        self.seq_length = seq_length
        
        self.tensor_in = tensor_in
        self.tensor_out = tensor_out
        
        self.create_batches()
        self.reset_batch_pointer()

    def reset_batch_pointer(self):
        self.pointer = 0

    def create_batches(self):
        self.num_batches = int(self.tensor_in.size / (self.batch_size * self.seq_length))
        self.tensor_in = self.tensor_in[:self.num_batches * self.batch_size * self.seq_length]
        self.tensor_out = self.tensor_out[:self.num_batches * self.batch_size * self.seq_length]
        
        # When the data (tesor) is too small, let's give them a better error message
        if self.num_batches==0:
            assert False, "Not enough data. Make seq_length and batch_size small."
        
        self.x_batches = np.split(self.tensor_in.reshape(self.batch_size, -1), self.num_batches, 1)
        self.y_batches = np.split(self.tensor_out.reshape(self.batch_size, -1), self.num_batches, 1)

    def next_batch(self):
        x, y = self.x_batches[self.pointer], self.y_batches[self.pointer]
        self.pointer += 1
        return x, y

class CopyBatchGenerator(BatchGenerator):
    
    def __init__(self, data, batch_size, seq_length):
        """初始化batch产生器
        Input:
            batch_size: 每一个mini-batch里面有多少样本。
            seq_length: 每一个样本的长度，和batch_size一起决定了每个minibatch的数据量。
        """
        self.batch_size = batch_size
        self.seq_length = seq_length
        
        tensor_in = np.array(data)
        tensor_out = np.copy(tensor_in)
        tensor_out[:-1] = tensor_in[1:]
        tensor_out[-1] = tensor_in[0]
        
        super(CopyBatchGenerator, self).__init__(tensor_in, tensor_out, batch_size, seq_length)

# %% [markdown]
# # 准备阶段
#
# #### 1. 使用python的argparse工具 集中处理超参数
#
# * `argparse`用法比较直观，相对晦涩一些的语法是 **`action = store_true`**
#
# ```python
# logging_args.add_argument('--debug', dest='debug',
#             action='store_true',
#             help='show debug information')
# ```
# * 当模型比较复杂的时候，使用add_argument_group()将各种options分组

# %%
import argparse
import numpy as np

def config_train(args=''):
    parser = argparse.ArgumentParser()

    # hyper-parameters to configure the datasets.
    # 数据相关的超参数
    data_args = parser.add_argument_group('Dataset Options')
    data_args.add_argument('--data_file', type = str,
            default = 'data/ice_and_fire_zh/ice_and_fire_utf8.txt',
            help = 'data file')
    data_args.add_argument('--encoding', type = str, default = 'utf-8',
            help = 'the encoding format of data file.')
    data_args.add_argument('--num_unrollings', type=int, default=20,
            help='number of unrolling steps.')
    data_args.add_argument('--train_frac', type = float, default=0.9,
            help='fraction of data used for training.')
    data_args.add_argument('--valid_frac', type=float, default=0.05,
            help='fraction of data used for validation.')
    # test_frac is computed as (1 - train_frac - valid_frac).


    # hyper-parameters to configure the neural network.
    # 模型结构相关的超参数
    network_args = parser.add_argument_group('Model Arch Options')
    network_args.add_argument('--embedding_size', type=int, default=128,
            help='size of character embeddings, 0 for one-hot')
    network_args.add_argument('--hidden_size', type=int, default=256,
            help='size of RNN hidden state vector')
    network_args.add_argument('--cell_type', type=str, default='lstm',
            help='which RNN cell to use (rnn, lstm or gru).')
    network_args.add_argument('--num_layers', type=int, default=2,
            help='number of layers in the RNN')


    # hyper-parameters to control the training.
    # 训练和优化相关的超参数
    training_args = parser.add_argument_group('Model Training Options')
    # 1. Parameters for iterating through samples
    training_args.add_argument('--num_epochs', type = int, default=50,
            help='number of epochs')
    training_args.add_argument('--batch_size', type = int, default=20,
            help='minibatch size')
    # 2. Parameters for dropout setting.
    training_args.add_argument('--dropout', type=float, default=0.0,
            help='dropout rate, default to 0 (no dropout).')
    training_args.add_argument('--input_dropout', type=float, default=0.0,
            help=('dropout rate on input layer, default to 0 (no dropout),'
                'and no dropout if using one-hot representation.'))
    # 3. Parameters for gradient descent.
    training_args.add_argument('--max_grad_norm', type=float, default=5.,
            help='clip global grad norm')
    training_args.add_argument('--learning_rate', type=float, default=5e-3,
            help='initial learning rate')


    # Parameters for manipulating logging and saving models.
    # 学习日志和结果相关的超参数
    logging_args = parser.add_argument_group('Logging Options')
    # 1. Directory to output models and other records.
    logging_args.add_argument('--output_dir', type = str,
            default = 'demo_model',
            help = ('directory to store final and'
            ' intermediate results and models'))
    # 2. Parameters for printing messages.
    logging_args.add_argument('--progress_freq', type=int, default=100,
            help=('frequency for progress report in training and evalution.'))
    logging_args.add_argument('--verbose', type=int, default=0,
            help=('whether to show progress report in training and evalution.'))
    logging_args.add_argument('--debug', dest='debug',action='store_true',
            help='show debug information')
    logging_args.add_argument('--test', dest='test', action='store_true',
            help=('parameter for unittesting. Use the first 1000 '
                'character to as data to test the implementation'))
    # 3. Parameters to feed in the initial model and current best model.
    logging_args.add_argument('--init_model', type=str,
            default='', help=('initial model'))
    logging_args.add_argument('--best_model', type=str,
            default='', help=('current best model'))
    logging_args.add_argument('--best_valid_ppl', type=float,
            default=np.Inf, help=('current valid perplexity'))
    # 4. Parameters for using saved best models.
    logging_args.add_argument('--init_dir', type=str, default='',
            help='continue from the outputs in the given directory')
    
    args = parser.parse_args(args.split())
    
    return args


def config_sample(args=''):
    parser = argparse.ArgumentParser()
    
    # hyper-parameters for using saved best models.
    # 学习日志和结果相关的超参数
    logging_args = parser.add_argument_group('Logging_Options')
    logging_args.add_argument('--init_dir', type=str,
            default='demo_model/',
            help='continue from the outputs in the given directory')

    # hyper-parameters for sampling.
    # 设置sampling相关的超参数
    testing_args = parser.add_argument_group('Sampling Options')
    testing_args.add_argument('--max_prob', dest='max_prob', action='store_true',
                        help='always pick the most probable next character in sampling')
    testing_args.set_defaults(max_prob=False)

    testing_args.add_argument('--start_text', type=str,
                        default='The meaning of life is ',
                        help='the text to start with')

    testing_args.add_argument('--length', type=int,
                        default=100,
                        help='length of sampled sequence')

    testing_args.add_argument('--seed', type=int,
                        default=-1,
                        help=('seed for sampling to replicate results, '
                              'an integer between 0 and 4294967295.'))

    args = parser.parse_args(args.split())

    return args

# %%
args = config_train('--debug --verbose 1')
vars(args)
# Out:
# {'batch_size': 20,
#  'best_model': '',
#  'best_valid_ppl': inf,
#  'cell_type': 'lstm',
#  'data_file': 'data/ice_and_fire_zh/ice_and_fire_utf8.txt',
#  'debug': True,
#  'dropout': 0.0,
#  'embedding_size': 128,
#  'encoding': 'utf-8',
#  'hidden_size': 256,
#  'init_dir': '',
#  'init_model': '',
#  'input_dropout': 0.0,
#  'learning_rate': 0.005,
#  'max_grad_norm': 5.0,
#  'num_epochs': 50,
#  'num_layers': 2,
#  'num_unrollings': 20,
#  'output_dir': 'demo_model',
#  'progress_freq': 100,
#  'test': False,
#  'train_frac': 0.9,
#  'valid_frac': 0.05,
#  'verbose': 1}

# %% [markdown]
# # 准备阶段
#
# #### 2. 处理文件地址，预备 模型的记录，保存，读取操作

# %%
import os

# 在目标文件夹（output_dir)里面创建
# save_model, best_model 和 tensorboar_log
# 分别保存
#   1. 训练练过程中的中间模型
#   2. 目前最好的模型
#   3. 用于tensorboard可视化的日志文件

args.save_model = os.path.join(args.output_dir, 'save_model/model')
args.save_best_model = os.path.join(args.output_dir, 'best_model/model')
args.tb_log_dir = os.path.join(args.output_dir, 'tensorboard_log/')
args.vocab_file = ''

# 小心使用，如果目标文件夹已经存在，先将其删除
print('=' * 80)
print('All final and intermediate outputs will be stored in %s/' % 
      args.output_dir)
print('=' * 80 + '\n')
if os.path.exists(args.output_dir):
    import shutil
    shutil.rmtree(args.output_dir)

# 建立目标文件夹和子文件夹
for paths in [args.save_model, args.save_best_model, args.tb_log_dir]:
    os.makedirs(os.path.dirname(paths))
# Out:
# ================================================================================
# All final and intermediate outputs will be stored in demo_model/
# ================================================================================

# %%
print('模型将保存在：%s' % args.save_model)
print('最好的模型将保存在：%s' % args.save_best_model)
print('tensorboard相关文件将保存在：%s' % args.tb_log_dir)
# Out:
# 模型将保存在：demo_model/save_model/model
# 最好的模型将保存在：demo_model/best_model/model
# tensorboard相关文件将保存在：demo_model/tensorboard_log/

# %%
import logging
import sys
logging.basicConfig(stream=sys.stdout,
                    format='%(asctime)s %(levelname)s:%(message)s',
                    level=logging.INFO, datefmt='%I:%M:%S')
logging
# Out:
# <module 'logging' from '/home/dong/anaconda3/lib/python3.6/logging/__init__.py'>

# %%
if args.debug:
    logging.info('args are:\n%s', args)

if len(args.init_dir) != 0:
    with open(os.path.join(args.init_dir, 'result.json'), 'r') as f:
        result = json.load(f)
        
    params = result['params']
    args.init_model = result['latest_model']
    best_model = result['best_model']
    best_valid_ppl = result['best_valid_ppl']
    
    if 'encoding' in result:
        args.encoding = result['encoding']
    else:
        args.encoding = 'utf-8'
    args.vocab_file = os.path.join(args.init_dir, 'vocab.json')
    
else:
    params = {'batch_size': args.batch_size,
              'num_unrollings': args.num_unrollings,
              'hidden_size': args.hidden_size,
              'max_grad_norm': args.max_grad_norm,
              'embedding_size': args.embedding_size,
              'num_layers': args.num_layers,
              'learning_rate': args.learning_rate,
              'cell_type': args.cell_type,
              'dropout': args.dropout,
              'input_dropout': args.input_dropout}
    best_model = ''

import json
logging.info('\n\nParameters are:\n%s\n',
             json.dumps(params, sort_keys=True, indent=4))
# Out:
# 06:12:53 INFO:args are:
# Namespace(batch_size=20, best_model='', best_valid_ppl=inf, cell_type='lstm', data_file='data/ice_and_fire_zh/ice_and_fire_utf8.txt', debug=True, dropout=0.0, embedding_size=128, encoding='utf-8', hidden_size=256, init_dir='', init_model='', input_dropout=0.0, learning_rate=0.005, max_grad_norm=5.0, num_epochs=50, num_layers=2, num_unrollings=20, output_dir='demo_model', progress_freq=100, save_best_model='demo_model/best_model/model', save_model='demo_model/save_model/model', tb_log_dir='demo_model/tensorboard_log/', test=False, train_frac=0.9, valid_frac=0.05, verbose=1, vocab_file='')
# 06:12:53 INFO:
#
# Parameters are:
# {
#     "batch_size": 20,
#     "cell_type": "lstm",
#     "dropout": 0.0,
#     "embedding_size": 128,
#     "hidden_size": 256,
#     "input_dropout": 0.0,
#     "learning_rate": 0.005,
#     "max_grad_norm": 5.0,
#     "num_layers": 2,
#     "num_unrollings": 20
# }

# %%
import json
params = {'batch_size': args.batch_size,
          'num_unrollings': args.num_unrollings,
          'hidden_size': args.hidden_size,
          'max_grad_norm': args.max_grad_norm,
          'embedding_size': args.embedding_size,
          'num_layers': args.num_layers,
          'learning_rate': args.learning_rate,
          'cell_type': args.cell_type,
          'dropout': args.dropout,
          'input_dropout': args.input_dropout}
s_params= json.dumps(params, sort_keys=True, indent = 4)

# %%
args.data_file
# Out:
# 'data/ice_and_fire_zh/ice_and_fire_utf8.txt'

# %%
import codecs
# codecs: python的编码和解码模块, 可以参考
# http://blog.csdn.net/iamaiearner/article/details/9138865
# http://www.cnblogs.com/TsengYuen/archive/2012/05/22/2513290.html
# http://blog.csdn.net/suofiya2008/article/details/5579413
# 等博客

# Read and split data.
logging.info('Reading data from: %s', args.data_file)
with codecs.open(args.data_file, encoding=args.encoding) as f:
    text = f.read()

if args.test:
    text = text[:50000]
logging.info('Number of characters: %s', len(text))

if args.debug:
    logging.info('First %d characters: %s', 10, text[:10])
# Out:
# 06:12:59 INFO:Reading data from: data/ice_and_fire_zh/ice_and_fire_utf8.txt
# 06:12:59 INFO:Number of characters: 3272648
# 06:12:59 INFO:First 10 characters: 《冰与火之歌》全集（

# %% [markdown]
# ### 将整本数据集分割成train, test, validation数据集

# %%
logging.info('Creating train, valid, test split')
train_size = int(args.train_frac * len(text))
valid_size = int(args.valid_frac * len(text))
test_size = len(text) - train_size - valid_size
train_text = text[:train_size]
valid_text = text[train_size:train_size + valid_size]
test_text = text[train_size + valid_size:]
# Out:
# 06:13:02 INFO:Creating train, valid, test split

# %% [markdown]
# ### 建立词典

# %%
vocab_loader = VocabularyLoader()
if len(args.vocab_file) != 0:
    vocab_loader.load_vocab(args.vocab_file, args.encoding)
else:
    logging.info('Creating vocabulary')
    vocab_loader.create_vocab(text)
    vocab_file = os.path.join(args.output_dir, 'vocab.json')
    vocab_loader.save_vocab(vocab_file, args.encoding)
    logging.info('Vocabulary is saved in %s', vocab_file)
    args.vocab_file = vocab_file

params['vocab_size'] = vocab_loader.vocab_size
logging.info('Vocab size: %d\n', vocab_loader.vocab_size)

logging.info('sampled words in vocabulary %s ' % list(zip(list(vocab_loader.index_vocab_dict.keys())[:1000:100], 
         list(vocab_loader.index_vocab_dict.values())[:1000:100])))
# Out:
# 06:13:04 INFO:Creating vocabulary
# 06:13:05 INFO:Vocabulary is saved in demo_model/vocab.json
# 06:13:05 INFO:Vocab size: 4422
#
# 06:13:05 INFO:sampled words in vocabulary [(0, '宫'), (100, '佐'), (200, '湮'), (300, 'c'), (400, '艳'), (500, '潜'), (600, '窸'), (700, '绕'), (800, '袂'), (900, '侦')]

# %%
# Create batch generators.
batch_size = params['batch_size']
num_unrollings = params['num_unrollings']

train_batches = CopyBatchGenerator(list(map(vocab_loader.vocab_index_dict.get, train_text)), batch_size, num_unrollings)
valid_batches = CopyBatchGenerator(list(map(vocab_loader.vocab_index_dict.get, valid_text)), batch_size, num_unrollings)
test_batches = CopyBatchGenerator(list(map(vocab_loader.vocab_index_dict.get, test_text)), batch_size, num_unrollings)

# %% [markdown]
# ### 一个训练样本是这个样子的：
# * input： 《冰与火之歌》全集（1-5卷）【实体书精
# * output：  冰与火之歌》全集（1-5卷）【实体书精校

# %%
logging.info('Test the batch generators')
x, y = train_batches.next_batch()
print(x[0])
logging.info((str(x[0]), str(batche2string(x[0], vocab_loader.index_vocab_dict))))
logging.info((str(y[0]), str(batche2string(y[0], vocab_loader.index_vocab_dict))))
# Out:
# 06:13:10 INFO:Test the batch generators
# [4251 1963 2440 3218 2370 1032 4014 2723  741 3839 2792 2884 3180 3721  420
#  1742  392 4226  598 2930]
# 06:13:10 INFO:('[4251 1963 2440 3218 2370 1032 4014 2723  741 3839 2792 2884 3180 3721  420\n 1742  392 4226  598 2930]', '《冰与火之歌》全集（1-5卷）【实体书精')
# 06:13:10 INFO:('[1963 2440 3218 2370 1032 4014 2723  741 3839 2792 2884 3180 3721  420 1742\n  392 4226  598 2930 2235]', '冰与火之歌》全集（1-5卷）【实体书精校')

# %%
# 建立训练，valid，测试 对象
logging.info('Creating graph')
graph = tf.Graph()
with graph.as_default():
    with tf.name_scope('training'):
        train_model = CharRNNLM(is_training=True, infer=False, **params)
    
    tf.get_variable_scope().reuse_variables()
    with tf.name_scope('validation'):
        valid_model = CharRNNLM(is_training=False, infer=False, **params)
    
    with tf.name_scope('evaluation'):
        test_model = CharRNNLM(is_training=False, infer=False, **params)
        saver = tf.train.Saver(name='model_saver')
        best_model_saver = tf.train.Saver(name='best_model_saver')

logging.info('Start training\n')

result = {}
result['params'] = params
result['vocab_file'] = args.vocab_file
result['encoding'] = args.encoding
# Out:
# 06:13:11 INFO:Creating graph
# 06:13:14 INFO:Start training

# %% [markdown]
# Loop: ========================
#
#     Training: ----------------------------
#         + One Epoch Training Data
#         + Update Parameters
#         + Save Updated Parameters
#     Evaluation: ----------------------------
#         + One Epoch Validation/Heldout Data
#         + Evaluate Performance of Parameters
#         + Update and Save Best Parameters, if New Best
#
# Test: ----------------------------
#     + Restore Best Model
#     + One Epoch Testing Data

# %%
try:
    with tf.Session(graph=graph) as session:
        graph_info = session.graph_def
        
        train_writer = tf.summary.FileWriter(
            args.tb_log_dir + 'train/', graph_info)
        valid_writer = tf.summary.FileWriter(
            args.tb_log_dir + 'valid/', graph_info)
        
        # load a saved model or start from random initialization.
        if len(args.init_model) != 0:
            saver.restore(session, args.init_model)
        else:
            tf.global_variables_initializer().run()

        learning_rate = args.learning_rate
        for epoch in range(args.num_epochs):
            logging.info('=' * 19 + ' Epoch %d ' + '=' * 19 + '\n',epoch)
            logging.info('Training on training set')
            
            ## 第一部分.
            # training step, running one epoch on training data
            ppl, train_summary_str, global_step = train_model.run_epoch(
                session, train_batches, is_training=True,
                learning_rate=learning_rate, verbose=args.verbose,
                freq=args.progress_freq)
            # record the summary
            train_writer.add_summary(train_summary_str, global_step)
            train_writer.flush()
            # save model
            # 注意：save操作在session内部才有意义！
            saved_path = saver.save(session, args.save_model,
                                    global_step=train_model.global_step)
            logging.info('Latest model saved in %s\n', saved_path)
            
            ## 第二部分.
            # evaluation step, running one epoch on validation data
            logging.info('Evaluate on validation set')
            valid_ppl, valid_summary_str, _ = valid_model.run_epoch(
                session, valid_batches, is_training=False,
                learning_rate=learning_rate, verbose=args.verbose,
                freq=args.progress_freq)
            # save and update best model
            if (len(best_model) == 0) or (valid_ppl < best_valid_ppl):
                best_model = best_model_saver.save(
                    session, args.save_best_model,
                    global_step=train_model.global_step)
                best_valid_ppl = valid_ppl
            else:
                learning_rate /= 2.0
                logging.info('Decay the learning rate: ' + str(learning_rate))
            valid_writer.add_summary(valid_summary_str, global_step)
            valid_writer.flush()
            logging.info('Best model is saved in %s', best_model)
            logging.info('Best validation ppl is %f\n', best_valid_ppl)

            ## 第三部分.
            # update readable summary
            result['latest_model'] = saved_path
            result['best_model'] = best_model
            # Convert to float because numpy.float is not json serializable.
            result['best_valid_ppl'] = float(best_valid_ppl)

            result_path = os.path.join(args.output_dir, 'result.json')
            if os.path.exists(result_path):
                os.remove(result_path)
            with open(result_path, 'w') as f:
                json.dump(result, f, indent=2, sort_keys=True)

        logging.info('Latest model is saved in %s', saved_path)
        logging.info('Best model is saved in %s', best_model)
        logging.info('Best validation ppl is %f\n', best_valid_ppl)

        logging.info('Evaluate the best model on test set')
        saver.restore(session, best_model)
        test_ppl, _, _ = test_model.run_epoch(session, test_batches, is_training=False,
                                 learning_rate=learning_rate, verbose=args.verbose, freq=args.progress_freq)
        result['test_ppl'] = float(test_ppl)
finally:
    result_path = os.path.join(args.output_dir, 'result.json')
    if os.path.exists(result_path):
        os.remove(result_path)
    with open(result_path, 'w') as f:
        json.dump(result, f, indent=2, sort_keys=True)
# Out:
# WARNING:tensorflow:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# 06:13:22 WARNING:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# WARNING:tensorflow:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# 06:13:22 WARNING:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# 06:13:23 INFO:=================== Epoch 0 ===================
#
# 06:13:23 INFO:Training on training set
# 06:13:23 INFO:epoch_size: 7363
# 06:13:23 INFO:data_size: 20
# 06:13:23 INFO:num_unrollings: 20
# 06:13:23 INFO:batch_size: 20
# 06:13:25 INFO:1.4%, step:99, perplexity: 1326.914, speed: 22737 words
# 06:13:26 INFO:2.7%, step:199, perplexity: 1024.268, speed: 25260 words
# 06:13:28 INFO:4.1%, step:299, perplexity: 873.477, speed: 26392 words
# 06:13:29 INFO:5.4%, step:399, perplexity: 775.797, speed: 26978 words
# 06:13:30 INFO:6.8%, step:499, perplexity: 704.646, speed: 27367 words
# 06:13:32 INFO:8.1%, step:599, perplexity: 651.455, speed: 27605 words
# 06:13:33 INFO:9.5%, step:699, perplexity: 609.321, speed: 27759 words
# 06:13:34 INFO:10.9%, step:799, perplexity: 574.812, speed: 27848 words
# 06:13:36 INFO:12.2%, step:899, perplexity: 545.829, speed: 27890 words
# 06:13:37 INFO:13.6%, step:999, perplexity: 520.532, speed: 27936 words
# 06:13:39 INFO:14.9%, step:1099, perplexity: 498.240, speed: 27996 words
# 06:13:40 INFO:16.3%, step:1199, perplexity: 478.468, speed: 28070 words
# 06:13:41 INFO:17.7%, step:1299, perplexity: 460.708, speed: 28138 words
# 06:13:43 INFO:19.0%, step:1399, perplexity: 444.714, speed: 28192 words
# 06:13:44 INFO:20.4%, step:1499, perplexity: 430.201, speed: 28207 words
# 06:13:46 INFO:21.7%, step:1599, perplexity: 416.935, speed: 28259 words
# 06:13:47 INFO:23.1%, step:1699, perplexity: 404.798, speed: 28305 words
# 06:13:48 INFO:24.4%, step:1799, perplexity: 393.672, speed: 28331 words
# 06:13:50 INFO:25.8%, step:1899, perplexity: 383.382, speed: 28318 words
# 06:13:51 INFO:27.2%, step:1999, perplexity: 373.793, speed: 28323 words
# 06:13:53 INFO:28.5%, step:2099, perplexity: 364.862, speed: 28351 words
# 06:13:54 INFO:29.9%, step:2199, perplexity: 356.503, speed: 28379 words
# 06:13:55 INFO:31.2%, step:2299, perplexity: 348.691, speed: 28393 words
# 06:13:57 INFO:32.6%, step:2399, perplexity: 341.386, speed: 28414 words
# 06:13:58 INFO:34.0%, step:2499, perplexity: 334.512, speed: 28445 words
# 06:14:00 INFO:35.3%, step:2599, perplexity: 328.017, speed: 28468 words
# 06:14:01 INFO:36.7%, step:2699, perplexity: 321.891, speed: 28487 words
# 06:14:02 INFO:38.0%, step:2799, perplexity: 316.096, speed: 28504 words
# 06:14:04 INFO:39.4%, step:2899, perplexity: 310.602, speed: 28518 words
# 06:14:05 INFO:40.7%, step:2999, perplexity: 305.377, speed: 28530 words
# 06:14:06 INFO:42.1%, step:3099, perplexity: 300.400, speed: 28538 words
# 06:14:08 INFO:43.5%, step:3199, perplexity: 295.653, speed: 28546 words
# 06:14:09 INFO:44.8%, step:3299, perplexity: 291.113, speed: 28547 words
# 06:14:11 INFO:46.2%, step:3399, perplexity: 286.765, speed: 28562 words
# 06:14:12 INFO:47.5%, step:3499, perplexity: 282.600, speed: 28572 words
# 06:14:13 INFO:48.9%, step:3599, perplexity: 278.610, speed: 28582 words
# 06:14:15 INFO:50.3%, step:3699, perplexity: 274.776, speed: 28588 words
# 06:14:16 INFO:51.6%, step:3799, perplexity: 271.095, speed: 28598 words
# 06:14:18 INFO:53.0%, step:3899, perplexity: 267.557, speed: 28601 words
# 06:14:19 INFO:54.3%, step:3999, perplexity: 264.150, speed: 28609 words
# 06:14:20 INFO:55.7%, step:4099, perplexity: 260.869, speed: 28609 words
# 06:14:22 INFO:57.0%, step:4199, perplexity: 257.701, speed: 28617 words
# 06:14:23 INFO:58.4%, step:4299, perplexity: 254.636, speed: 28619 words
# 06:14:24 INFO:59.8%, step:4399, perplexity: 251.675, speed: 28627 words
# 06:14:26 INFO:61.1%, step:4499, perplexity: 248.813, speed: 28630 words
# 06:14:27 INFO:62.5%, step:4599, perplexity: 246.044, speed: 28637 words
# 06:14:29 INFO:63.8%, step:4699, perplexity: 243.360, speed: 28629 words
# 06:14:30 INFO:65.2%, step:4799, perplexity: 240.760, speed: 28636 words
# 06:14:31 INFO:66.5%, step:4899, perplexity: 238.240, speed: 28634 words
# 06:14:33 INFO:67.9%, step:4999, perplexity: 235.797, speed: 28634 words
# 06:14:34 INFO:69.3%, step:5099, perplexity: 233.429, speed: 28638 words
# 06:14:36 INFO:70.6%, step:5199, perplexity: 231.133, speed: 28633 words
# 06:14:37 INFO:72.0%, step:5299, perplexity: 228.903, speed: 28630 words
# 06:14:38 INFO:73.3%, step:5399, perplexity: 226.736, speed: 28637 words
# 06:14:40 INFO:74.7%, step:5499, perplexity: 224.630, speed: 28644 words
# 06:14:41 INFO:76.1%, step:5599, perplexity: 222.582, speed: 28649 words
# 06:14:43 INFO:77.4%, step:5699, perplexity: 220.589, speed: 28646 words
# 06:14:44 INFO:78.8%, step:5799, perplexity: 218.647, speed: 28650 words
# 06:14:45 INFO:80.1%, step:5899, perplexity: 216.755, speed: 28651 words
# 06:14:47 INFO:81.5%, step:5999, perplexity: 214.914, speed: 28647 words
# 06:14:48 INFO:82.8%, step:6099, perplexity: 213.116, speed: 28641 words
# 06:14:50 INFO:84.2%, step:6199, perplexity: 211.364, speed: 28640 words
# 06:14:51 INFO:85.6%, step:6299, perplexity: 209.653, speed: 28643 words
# 06:14:52 INFO:86.9%, step:6399, perplexity: 207.987, speed: 28647 words
# 06:14:54 INFO:88.3%, step:6499, perplexity: 206.362, speed: 28652 words
# 06:14:55 INFO:89.6%, step:6599, perplexity: 204.775, speed: 28653 words
# 06:14:57 INFO:91.0%, step:6699, perplexity: 203.223, speed: 28637 words
# 06:14:58 INFO:92.4%, step:6799, perplexity: 201.706, speed: 28633 words
# 06:14:59 INFO:93.7%, step:6899, perplexity: 200.222, speed: 28623 words
# 06:15:01 INFO:95.1%, step:6999, perplexity: 198.770, speed: 28625 words
# 06:15:02 INFO:96.4%, step:7099, perplexity: 197.350, speed: 28625 words
# 06:15:04 INFO:97.8%, step:7199, perplexity: 195.958, speed: 28622 words
# 06:15:05 INFO:99.1%, step:7299, perplexity: 194.595, speed: 28623 words
# 06:15:06 INFO:Perplexity: 95.610, speed: 28625 words per sec
# 06:15:06 INFO:Latest model saved in demo_model/save_model/model-7363
#
# 06:15:06 INFO:Evaluate on validation set
# 06:15:06 INFO:epoch_size: 409
# 06:15:06 INFO:data_size: 20
# 06:15:06 INFO:num_unrollings: 20
# 06:15:06 INFO:batch_size: 20
# 06:15:07 INFO:24.4%, step:99, perplexity: 79.895, speed: 66020 words
# 06:15:07 INFO:48.9%, step:199, perplexity: 80.491, speed: 68890 words
# 06:15:08 INFO:73.3%, step:299, perplexity: 80.330, speed: 70453 words
# 06:15:09 INFO:97.8%, step:399, perplexity: 79.989, speed: 71184 words
# 06:15:09 INFO:Perplexity: 78.968, speed: 71179 words per sec
# 06:15:09 INFO:Best model is saved in demo_model/best_model/model-7363
# 06:15:09 INFO:Best validation ppl is 78.967819
#
# 06:15:09 INFO:=================== Epoch 1 ===================
#
# 06:15:09 INFO:Training on training set
# 06:15:09 INFO:epoch_size: 7363
# 06:15:09 INFO:data_size: 20
# 06:15:09 INFO:num_unrollings: 20
# 06:15:09 INFO:batch_size: 20
# 06:15:10 INFO:1.4%, step:99, perplexity: 62.599, speed: 28550 words
# 06:15:12 INFO:2.7%, step:199, perplexity: 62.977, speed: 28484 words
# 06:15:13 INFO:4.1%, step:299, perplexity: 63.386, speed: 28320 words
# 06:15:15 INFO:5.4%, step:399, perplexity: 63.198, speed: 28401 words
# 06:15:16 INFO:6.8%, step:499, perplexity: 62.778, speed: 28475 words
# 06:15:17 INFO:8.1%, step:599, perplexity: 62.515, speed: 28485 words
# 06:15:19 INFO:9.5%, step:699, perplexity: 62.257, speed: 28501 words
# 06:15:20 INFO:10.9%, step:799, perplexity: 62.020, speed: 28504 words
# 06:15:22 INFO:12.2%, step:899, perplexity: 61.839, speed: 28465 words
# 06:15:23 INFO:13.6%, step:999, perplexity: 61.614, speed: 28371 words
# 06:15:24 INFO:14.9%, step:1099, perplexity: 61.368, speed: 28327 words
# 06:15:26 INFO:16.3%, step:1199, perplexity: 61.133, speed: 28328 words
# 06:15:27 INFO:17.7%, step:1299, perplexity: 60.900, speed: 28340 words
# 06:15:29 INFO:19.0%, step:1399, perplexity: 60.686, speed: 28374 words
# 06:15:30 INFO:20.4%, step:1499, perplexity: 60.486, speed: 28397 words
# 06:15:31 INFO:21.7%, step:1599, perplexity: 60.296, speed: 28420 words
# 06:15:33 INFO:23.1%, step:1699, perplexity: 60.126, speed: 28400 words
# 06:15:34 INFO:24.4%, step:1799, perplexity: 59.984, speed: 28405 words
# 06:15:36 INFO:25.8%, step:1899, perplexity: 59.855, speed: 28417 words
# 06:15:37 INFO:27.2%, step:1999, perplexity: 59.728, speed: 28423 words
# 06:15:38 INFO:28.5%, step:2099, perplexity: 59.608, speed: 28428 words
# 06:15:40 INFO:29.9%, step:2199, perplexity: 59.494, speed: 28448 words
# 06:15:41 INFO:31.2%, step:2299, perplexity: 59.391, speed: 28452 words
# 06:15:43 INFO:32.6%, step:2399, perplexity: 59.306, speed: 28449 words
# 06:15:44 INFO:34.0%, step:2499, perplexity: 59.226, speed: 28436 words
# 06:15:46 INFO:35.3%, step:2599, perplexity: 59.149, speed: 28414 words
# 06:15:47 INFO:36.7%, step:2699, perplexity: 59.081, speed: 28410 words
# 06:15:48 INFO:38.0%, step:2799, perplexity: 59.019, speed: 28365 words
# 06:15:50 INFO:39.4%, step:2899, perplexity: 58.963, speed: 28322 words
# 06:15:51 INFO:40.7%, step:2999, perplexity: 58.909, speed: 28288 words
# 06:15:53 INFO:42.1%, step:3099, perplexity: 58.856, speed: 28281 words
# 06:15:54 INFO:43.5%, step:3199, perplexity: 58.806, speed: 28280 words
# 06:15:56 INFO:44.8%, step:3299, perplexity: 58.754, speed: 28265 words
# 06:15:57 INFO:46.2%, step:3399, perplexity: 58.702, speed: 28249 words
# 06:15:59 INFO:47.5%, step:3499, perplexity: 58.650, speed: 28234 words
# 06:16:00 INFO:48.9%, step:3599, perplexity: 58.600, speed: 28188 words
# 06:16:02 INFO:50.3%, step:3699, perplexity: 58.549, speed: 28117 words
# 06:16:03 INFO:51.6%, step:3799, perplexity: 58.500, speed: 28081 words
# 06:16:05 INFO:53.0%, step:3899, perplexity: 58.453, speed: 28067 words
# 06:16:06 INFO:54.3%, step:3999, perplexity: 58.405, speed: 28068 words
# 06:16:07 INFO:55.7%, step:4099, perplexity: 58.359, speed: 28075 words
# 06:16:09 INFO:57.0%, step:4199, perplexity: 58.312, speed: 28075 words
# 06:16:10 INFO:58.4%, step:4299, perplexity: 58.262, speed: 28077 words
# 06:16:12 INFO:59.8%, step:4399, perplexity: 58.211, speed: 28085 words
# 06:16:13 INFO:61.1%, step:4499, perplexity: 58.161, speed: 28092 words
# 06:16:14 INFO:62.5%, step:4599, perplexity: 58.111, speed: 28094 words
# 06:16:16 INFO:63.8%, step:4699, perplexity: 58.060, speed: 28100 words
# 06:16:17 INFO:65.2%, step:4799, perplexity: 58.009, speed: 28107 words
# 06:16:19 INFO:66.5%, step:4899, perplexity: 57.958, speed: 28113 words
# 06:16:20 INFO:67.9%, step:4999, perplexity: 57.907, speed: 28120 words
# 06:16:21 INFO:69.3%, step:5099, perplexity: 57.858, speed: 28125 words
# 06:16:23 INFO:70.6%, step:5199, perplexity: 57.810, speed: 28127 words
# 06:16:24 INFO:72.0%, step:5299, perplexity: 57.763, speed: 28129 words
# 06:16:26 INFO:73.3%, step:5399, perplexity: 57.716, speed: 28136 words
# 06:16:27 INFO:74.7%, step:5499, perplexity: 57.669, speed: 28146 words
# 06:16:29 INFO:76.1%, step:5599, perplexity: 57.623, speed: 28152 words
# 06:16:30 INFO:77.4%, step:5699, perplexity: 57.577, speed: 28160 words
# 06:16:31 INFO:78.8%, step:5799, perplexity: 57.531, speed: 28164 words
# 06:16:33 INFO:80.1%, step:5899, perplexity: 57.485, speed: 28172 words
# 06:16:34 INFO:81.5%, step:5999, perplexity: 57.440, speed: 28175 words
# 06:16:36 INFO:82.8%, step:6099, perplexity: 57.394, speed: 28181 words
# 06:16:37 INFO:84.2%, step:6199, perplexity: 57.348, speed: 28185 words
# 06:16:38 INFO:85.6%, step:6299, perplexity: 57.302, speed: 28191 words
# 06:16:40 INFO:86.9%, step:6399, perplexity: 57.257, speed: 28194 words
# 06:16:41 INFO:88.3%, step:6499, perplexity: 57.214, speed: 28196 words
# 06:16:43 INFO:89.6%, step:6599, perplexity: 57.171, speed: 28199 words
# 06:16:44 INFO:91.0%, step:6699, perplexity: 57.127, speed: 28204 words
# 06:16:45 INFO:92.4%, step:6799, perplexity: 57.082, speed: 28207 words
# 06:16:47 INFO:93.7%, step:6899, perplexity: 57.037, speed: 28209 words
# 06:16:48 INFO:95.1%, step:6999, perplexity: 56.993, speed: 28212 words
# 06:16:50 INFO:96.4%, step:7099, perplexity: 56.948, speed: 28215 words
# 06:16:51 INFO:97.8%, step:7199, perplexity: 56.902, speed: 28214 words
# 06:16:52 INFO:99.1%, step:7299, perplexity: 56.856, speed: 28217 words
# 06:16:53 INFO:Perplexity: 53.365, speed: 28219 words per sec
# 06:16:54 INFO:Latest model saved in demo_model/save_model/model-14726
#
# 06:16:54 INFO:Evaluate on validation set
# 06:16:54 INFO:epoch_size: 409
# 06:16:54 INFO:data_size: 20
# 06:16:54 INFO:num_unrollings: 20
# 06:16:54 INFO:batch_size: 20
# 06:16:54 INFO:24.4%, step:99, perplexity: 69.814, speed: 65394 words
# 06:16:55 INFO:48.9%, step:199, perplexity: 70.300, speed: 67494 words
# 06:16:56 INFO:73.3%, step:299, perplexity: 70.167, speed: 66896 words
# 06:16:56 INFO:97.8%, step:399, perplexity: 69.883, speed: 67395 words
# 06:16:56 INFO:Perplexity: 68.927, speed: 67485 words per sec
# 06:16:56 INFO:Best model is saved in demo_model/best_model/model-14726
# 06:16:56 INFO:Best validation ppl is 68.926933
#
# 06:16:56 INFO:=================== Epoch 2 ===================
#
# 06:16:56 INFO:Training on training set
# 06:16:56 INFO:epoch_size: 7363
# 06:16:56 INFO:data_size: 20
# 06:16:56 INFO:num_unrollings: 20
# 06:16:56 INFO:batch_size: 20
# 06:16:58 INFO:1.4%, step:99, perplexity: 49.066, speed: 28180 words
# 06:16:59 INFO:2.7%, step:199, perplexity: 49.600, speed: 28102 words
# 06:17:01 INFO:4.1%, step:299, perplexity: 50.187, speed: 27897 words
# 06:17:02 INFO:5.4%, step:399, perplexity: 50.231, speed: 27807 words
# 06:17:04 INFO:6.8%, step:499, perplexity: 50.043, speed: 27794 words
# 06:17:05 INFO:8.1%, step:599, perplexity: 49.940, speed: 27788 words
# 06:17:07 INFO:9.5%, step:699, perplexity: 49.826, speed: 27792 words
# 06:17:08 INFO:10.9%, step:799, perplexity: 49.717, speed: 27812 words
# 06:17:09 INFO:12.2%, step:899, perplexity: 49.644, speed: 27734 words
# 06:17:11 INFO:13.6%, step:999, perplexity: 49.535, speed: 27589 words
# 06:17:12 INFO:14.9%, step:1099, perplexity: 49.407, speed: 27533 words
# 06:17:14 INFO:16.3%, step:1199, perplexity: 49.283, speed: 27497 words
# 06:17:15 INFO:17.7%, step:1299, perplexity: 49.159, speed: 27347 words
# 06:17:17 INFO:19.0%, step:1399, perplexity: 49.046, speed: 27342 words
# 06:17:18 INFO:20.4%, step:1499, perplexity: 48.941, speed: 27387 words
# 06:17:20 INFO:21.7%, step:1599, perplexity: 48.841, speed: 27400 words
# 06:17:21 INFO:23.1%, step:1699, perplexity: 48.756, speed: 27452 words
# 06:17:23 INFO:24.4%, step:1799, perplexity: 48.692, speed: 27496 words
# 06:17:24 INFO:25.8%, step:1899, perplexity: 48.637, speed: 27532 words
# 06:17:25 INFO:27.2%, step:1999, perplexity: 48.583, speed: 27580 words
# 06:17:27 INFO:28.5%, step:2099, perplexity: 48.535, speed: 27619 words
# 06:17:28 INFO:29.9%, step:2199, perplexity: 48.490, speed: 27655 words
# 06:17:30 INFO:31.2%, step:2299, perplexity: 48.454, speed: 27682 words
# 06:17:31 INFO:32.6%, step:2399, perplexity: 48.430, speed: 27712 words
# 06:17:33 INFO:34.0%, step:2499, perplexity: 48.411, speed: 27730 words
# 06:17:34 INFO:35.3%, step:2599, perplexity: 48.392, speed: 27752 words
# 06:17:35 INFO:36.7%, step:2699, perplexity: 48.380, speed: 27775 words
# 06:17:37 INFO:38.0%, step:2799, perplexity: 48.372, speed: 27789 words
# 06:17:38 INFO:39.4%, step:2899, perplexity: 48.368, speed: 27810 words
# 06:17:40 INFO:40.7%, step:2999, perplexity: 48.364, speed: 27832 words
# 06:17:41 INFO:42.1%, step:3099, perplexity: 48.361, speed: 27849 words
# 06:17:42 INFO:43.5%, step:3199, perplexity: 48.358, speed: 27854 words
# 06:17:44 INFO:44.8%, step:3299, perplexity: 48.355, speed: 27874 words
# 06:17:45 INFO:46.2%, step:3399, perplexity: 48.349, speed: 27888 words
# 06:17:47 INFO:47.5%, step:3499, perplexity: 48.343, speed: 27899 words
# 06:17:48 INFO:48.9%, step:3599, perplexity: 48.339, speed: 27915 words
# 06:17:49 INFO:50.3%, step:3699, perplexity: 48.332, speed: 27929 words
# 06:17:51 INFO:51.6%, step:3799, perplexity: 48.327, speed: 27941 words
# 06:17:52 INFO:53.0%, step:3899, perplexity: 48.323, speed: 27952 words
# 06:17:54 INFO:54.3%, step:3999, perplexity: 48.318, speed: 27955 words
# 06:17:55 INFO:55.7%, step:4099, perplexity: 48.313, speed: 27962 words
# 06:17:57 INFO:57.0%, step:4199, perplexity: 48.307, speed: 27974 words
# 06:17:58 INFO:58.4%, step:4299, perplexity: 48.298, speed: 27985 words
# 06:17:59 INFO:59.8%, step:4399, perplexity: 48.288, speed: 27991 words
# 06:18:01 INFO:61.1%, step:4499, perplexity: 48.279, speed: 27998 words
# 06:18:02 INFO:62.5%, step:4599, perplexity: 48.268, speed: 28000 words
# 06:18:04 INFO:63.8%, step:4699, perplexity: 48.257, speed: 28003 words
# 06:18:05 INFO:65.2%, step:4799, perplexity: 48.244, speed: 28015 words
# 06:18:06 INFO:66.5%, step:4899, perplexity: 48.232, speed: 28026 words
# 06:18:08 INFO:67.9%, step:4999, perplexity: 48.219, speed: 28035 words
# 06:18:09 INFO:69.3%, step:5099, perplexity: 48.207, speed: 28043 words
# 06:18:11 INFO:70.6%, step:5199, perplexity: 48.196, speed: 28051 words
# 06:18:12 INFO:72.0%, step:5299, perplexity: 48.184, speed: 28056 words
# 06:18:13 INFO:73.3%, step:5399, perplexity: 48.173, speed: 28059 words
# 06:18:15 INFO:74.7%, step:5499, perplexity: 48.161, speed: 28067 words
# 06:18:16 INFO:76.1%, step:5599, perplexity: 48.150, speed: 28076 words
# 06:18:18 INFO:77.4%, step:5699, perplexity: 48.138, speed: 28084 words
# 06:18:19 INFO:78.8%, step:5799, perplexity: 48.126, speed: 28091 words
# 06:18:20 INFO:80.1%, step:5899, perplexity: 48.114, speed: 28085 words
# 06:18:22 INFO:81.5%, step:5999, perplexity: 48.103, speed: 28072 words
# 06:18:23 INFO:82.8%, step:6099, perplexity: 48.090, speed: 28077 words
# 06:18:25 INFO:84.2%, step:6199, perplexity: 48.076, speed: 28081 words
# 06:18:26 INFO:85.6%, step:6299, perplexity: 48.062, speed: 28087 words
# 06:18:28 INFO:86.9%, step:6399, perplexity: 48.049, speed: 28092 words
# 06:18:29 INFO:88.3%, step:6499, perplexity: 48.037, speed: 28092 words
# 06:18:30 INFO:89.6%, step:6599, perplexity: 48.024, speed: 28095 words
# 06:18:32 INFO:91.0%, step:6699, perplexity: 48.011, speed: 28097 words
# 06:18:33 INFO:92.4%, step:6799, perplexity: 47.996, speed: 28100 words
# 06:18:35 INFO:93.7%, step:6899, perplexity: 47.982, speed: 28105 words
# 06:18:36 INFO:95.1%, step:6999, perplexity: 47.966, speed: 28104 words
# 06:18:38 INFO:96.4%, step:7099, perplexity: 47.951, speed: 28103 words
# 06:18:39 INFO:97.8%, step:7199, perplexity: 47.934, speed: 28108 words
# 06:18:40 INFO:99.1%, step:7299, perplexity: 47.917, speed: 28112 words
# 06:18:41 INFO:Perplexity: 46.560, speed: 28115 words per sec
# 06:18:42 INFO:Latest model saved in demo_model/save_model/model-22089
#
# 06:18:42 INFO:Evaluate on validation set
# 06:18:42 INFO:epoch_size: 409
# 06:18:42 INFO:data_size: 20
# 06:18:42 INFO:num_unrollings: 20
# 06:18:42 INFO:batch_size: 20
# 06:18:42 INFO:24.4%, step:99, perplexity: 67.416, speed: 64259 words
# 06:18:43 INFO:48.9%, step:199, perplexity: 68.029, speed: 66501 words
# 06:18:43 INFO:73.3%, step:299, perplexity: 67.950, speed: 67169 words
# 06:18:44 INFO:97.8%, step:399, perplexity: 67.728, speed: 66731 words
# 06:18:44 INFO:Perplexity: 66.916, speed: 66556 words per sec
# 06:18:44 INFO:Best model is saved in demo_model/best_model/model-22089
# 06:18:44 INFO:Best validation ppl is 66.915535
#
# 06:18:44 INFO:=================== Epoch 3 ===================
#
# 06:18:44 INFO:Training on training set
# 06:18:44 INFO:epoch_size: 7363
# 06:18:44 INFO:data_size: 20
# 06:18:44 INFO:num_unrollings: 20
# 06:18:44 INFO:batch_size: 20
# 06:18:46 INFO:1.4%, step:99, perplexity: 44.348, speed: 28101 words
# 06:18:47 INFO:2.7%, step:199, perplexity: 44.953, speed: 28251 words
# 06:18:49 INFO:4.1%, step:299, perplexity: 45.529, speed: 28085 words
# 06:18:50 INFO:5.4%, step:399, perplexity: 45.602, speed: 27981 words
# 06:18:52 INFO:6.8%, step:499, perplexity: 45.456, speed: 27945 words
# 06:18:53 INFO:8.1%, step:599, perplexity: 45.376, speed: 27898 words
# 06:18:54 INFO:9.5%, step:699, perplexity: 45.283, speed: 27866 words
# 06:18:56 INFO:10.9%, step:799, perplexity: 45.194, speed: 27712 words
# 06:18:57 INFO:12.2%, step:899, perplexity: 45.136, speed: 27717 words
# 06:18:59 INFO:13.6%, step:999, perplexity: 45.048, speed: 27648 words
# 06:19:00 INFO:14.9%, step:1099, perplexity: 44.942, speed: 27687 words
# 06:19:02 INFO:16.3%, step:1199, perplexity: 44.839, speed: 27628 words
# 06:19:03 INFO:17.7%, step:1299, perplexity: 44.738, speed: 27648 words
# 06:19:05 INFO:19.0%, step:1399, perplexity: 44.646, speed: 27659 words
# 06:19:06 INFO:20.4%, step:1499, perplexity: 44.562, speed: 27556 words
# 06:19:08 INFO:21.7%, step:1599, perplexity: 44.483, speed: 27464 words
# 06:19:09 INFO:23.1%, step:1699, perplexity: 44.416, speed: 27490 words
# 06:19:11 INFO:24.4%, step:1799, perplexity: 44.370, speed: 27509 words
# 06:19:12 INFO:25.8%, step:1899, perplexity: 44.331, speed: 27529 words
# 06:19:13 INFO:27.2%, step:1999, perplexity: 44.295, speed: 27531 words
# 06:19:15 INFO:28.5%, step:2099, perplexity: 44.263, speed: 27563 words
# 06:19:16 INFO:29.9%, step:2199, perplexity: 44.236, speed: 27596 words
# 06:19:18 INFO:31.2%, step:2299, perplexity: 44.216, speed: 27615 words
# 06:19:19 INFO:32.6%, step:2399, perplexity: 44.207, speed: 27618 words
# 06:19:21 INFO:34.0%, step:2499, perplexity: 44.202, speed: 27624 words
# 06:19:22 INFO:35.3%, step:2599, perplexity: 44.198, speed: 27651 words
# 06:19:23 INFO:36.7%, step:2699, perplexity: 44.199, speed: 27681 words
# 06:19:25 INFO:38.0%, step:2799, perplexity: 44.204, speed: 27711 words
# 06:19:26 INFO:39.4%, step:2899, perplexity: 44.211, speed: 27735 words
# 06:19:28 INFO:40.7%, step:2999, perplexity: 44.218, speed: 27761 words
# 06:19:29 INFO:42.1%, step:3099, perplexity: 44.227, speed: 27780 words
# 06:19:30 INFO:43.5%, step:3199, perplexity: 44.235, speed: 27790 words
# 06:19:32 INFO:44.8%, step:3299, perplexity: 44.243, speed: 27798 words
# 06:19:33 INFO:46.2%, step:3399, perplexity: 44.249, speed: 27808 words
# 06:19:35 INFO:47.5%, step:3499, perplexity: 44.254, speed: 27818 words
# 06:19:36 INFO:48.9%, step:3599, perplexity: 44.260, speed: 27828 words
# 06:19:38 INFO:50.3%, step:3699, perplexity: 44.266, speed: 27839 words
# 06:19:39 INFO:51.6%, step:3799, perplexity: 44.272, speed: 27840 words
# 06:19:40 INFO:53.0%, step:3899, perplexity: 44.278, speed: 27851 words
# 06:19:42 INFO:54.3%, step:3999, perplexity: 44.283, speed: 27860 words
# 06:19:43 INFO:55.7%, step:4099, perplexity: 44.289, speed: 27877 words
# 06:19:45 INFO:57.0%, step:4199, perplexity: 44.294, speed: 27888 words
# 06:19:46 INFO:58.4%, step:4299, perplexity: 44.296, speed: 27904 words
# 06:19:47 INFO:59.8%, step:4399, perplexity: 44.297, speed: 27915 words
# 06:19:49 INFO:61.1%, step:4499, perplexity: 44.298, speed: 27925 words
# 06:19:50 INFO:62.5%, step:4599, perplexity: 44.298, speed: 27936 words
# 06:19:52 INFO:63.8%, step:4699, perplexity: 44.297, speed: 27944 words
# 06:19:53 INFO:65.2%, step:4799, perplexity: 44.295, speed: 27950 words
# 06:19:55 INFO:66.5%, step:4899, perplexity: 44.293, speed: 27959 words
# 06:19:56 INFO:67.9%, step:4999, perplexity: 44.291, speed: 27969 words
# 06:19:57 INFO:69.3%, step:5099, perplexity: 44.289, speed: 27977 words
# 06:19:59 INFO:70.6%, step:5199, perplexity: 44.288, speed: 27987 words
# 06:20:00 INFO:72.0%, step:5299, perplexity: 44.286, speed: 27999 words
# 06:20:02 INFO:73.3%, step:5399, perplexity: 44.285, speed: 28002 words
# 06:20:03 INFO:74.7%, step:5499, perplexity: 44.283, speed: 28010 words
# 06:20:04 INFO:76.1%, step:5599, perplexity: 44.281, speed: 28015 words
# 06:20:06 INFO:77.4%, step:5699, perplexity: 44.279, speed: 28023 words
# 06:20:07 INFO:78.8%, step:5799, perplexity: 44.277, speed: 28033 words
# 06:20:09 INFO:80.1%, step:5899, perplexity: 44.274, speed: 28041 words
# 06:20:10 INFO:81.5%, step:5999, perplexity: 44.272, speed: 28048 words
# 06:20:11 INFO:82.8%, step:6099, perplexity: 44.268, speed: 28056 words
# 06:20:13 INFO:84.2%, step:6199, perplexity: 44.264, speed: 28061 words
# 06:20:14 INFO:85.6%, step:6299, perplexity: 44.259, speed: 28067 words
# 06:20:16 INFO:86.9%, step:6399, perplexity: 44.255, speed: 28072 words
# 06:20:17 INFO:88.3%, step:6499, perplexity: 44.252, speed: 28078 words
# 06:20:18 INFO:89.6%, step:6599, perplexity: 44.248, speed: 28084 words
# 06:20:20 INFO:91.0%, step:6699, perplexity: 44.243, speed: 28089 words
# 06:20:21 INFO:92.4%, step:6799, perplexity: 44.238, speed: 28093 words
# 06:20:23 INFO:93.7%, step:6899, perplexity: 44.232, speed: 28097 words
# 06:20:24 INFO:95.1%, step:6999, perplexity: 44.225, speed: 28103 words
# 06:20:25 INFO:96.4%, step:7099, perplexity: 44.218, speed: 28104 words
# 06:20:27 INFO:97.8%, step:7199, perplexity: 44.210, speed: 28106 words
# 06:20:28 INFO:99.1%, step:7299, perplexity: 44.202, speed: 28109 words
# 06:20:29 INFO:Perplexity: 43.480, speed: 28112 words per sec
# 06:20:29 INFO:Latest model saved in demo_model/save_model/model-29452
#
# 06:20:29 INFO:Evaluate on validation set
# 06:20:29 INFO:epoch_size: 409
# 06:20:29 INFO:data_size: 20
# 06:20:29 INFO:num_unrollings: 20
# 06:20:29 INFO:batch_size: 20
# 06:20:30 INFO:24.4%, step:99, perplexity: 67.043, speed: 66277 words
# 06:20:31 INFO:48.9%, step:199, perplexity: 67.745, speed: 67876 words
# 06:20:31 INFO:73.3%, step:299, perplexity: 67.710, speed: 68717 words
# 06:20:32 INFO:97.8%, step:399, perplexity: 67.505, speed: 68146 words
# 06:20:32 INFO:Perplexity: 66.678, speed: 67969 words per sec
# 06:20:32 INFO:Best model is saved in demo_model/best_model/model-29452
# 06:20:32 INFO:Best validation ppl is 66.678246
#
# 06:20:32 INFO:=================== Epoch 4 ===================
#
# 06:20:32 INFO:Training on training set
# 06:20:32 INFO:epoch_size: 7363
# 06:20:32 INFO:data_size: 20
# 06:20:32 INFO:num_unrollings: 20
# 06:20:32 INFO:batch_size: 20
# 06:20:34 INFO:1.4%, step:99, perplexity: 41.874, speed: 27657 words
# 06:20:35 INFO:2.7%, step:199, perplexity: 42.469, speed: 27966 words
# 06:20:37 INFO:4.1%, step:299, perplexity: 43.037, speed: 27958 words
# 06:20:38 INFO:5.4%, step:399, perplexity: 43.140, speed: 27717 words
# 06:20:40 INFO:6.8%, step:499, perplexity: 43.031, speed: 27535 words
# 06:20:41 INFO:8.1%, step:599, perplexity: 42.975, speed: 27564 words
# 06:20:42 INFO:9.5%, step:699, perplexity: 42.902, speed: 27496 words
# 06:20:44 INFO:10.9%, step:799, perplexity: 42.827, speed: 27517 words
# 06:20:45 INFO:12.2%, step:899, perplexity: 42.783, speed: 27536 words
# 06:20:47 INFO:13.6%, step:999, perplexity: 42.709, speed: 27559 words
# 06:20:48 INFO:14.9%, step:1099, perplexity: 42.619, speed: 27477 words
# 06:20:50 INFO:16.3%, step:1199, perplexity: 42.531, speed: 27481 words
# 06:20:51 INFO:17.7%, step:1299, perplexity: 42.442, speed: 27339 words
# 06:20:53 INFO:19.0%, step:1399, perplexity: 42.362, speed: 27267 words
# 06:20:54 INFO:20.4%, step:1499, perplexity: 42.288, speed: 27287 words
# 06:20:56 INFO:21.7%, step:1599, perplexity: 42.218, speed: 27323 words
# 06:20:57 INFO:23.1%, step:1699, perplexity: 42.160, speed: 27348 words
# 06:20:59 INFO:24.4%, step:1799, perplexity: 42.122, speed: 27372 words
# 06:21:00 INFO:25.8%, step:1899, perplexity: 42.092, speed: 27405 words
# 06:21:01 INFO:27.2%, step:1999, perplexity: 42.064, speed: 27433 words
# 06:21:03 INFO:28.5%, step:2099, perplexity: 42.040, speed: 27434 words
# 06:21:04 INFO:29.9%, step:2199, perplexity: 42.020, speed: 27438 words
# 06:21:06 INFO:31.2%, step:2299, perplexity: 42.008, speed: 27469 words
# 06:21:07 INFO:32.6%, step:2399, perplexity: 42.006, speed: 27465 words
# 06:21:09 INFO:34.0%, step:2499, perplexity: 42.007, speed: 27472 words
# 06:21:10 INFO:35.3%, step:2599, perplexity: 42.009, speed: 27514 words
# 06:21:12 INFO:36.7%, step:2699, perplexity: 42.016, speed: 27545 words
# 06:21:13 INFO:38.0%, step:2799, perplexity: 42.025, speed: 27578 words
# 06:21:14 INFO:39.4%, step:2899, perplexity: 42.037, speed: 27596 words
# 06:21:16 INFO:40.7%, step:2999, perplexity: 42.050, speed: 27620 words
# 06:21:17 INFO:42.1%, step:3099, perplexity: 42.063, speed: 27634 words
# 06:21:19 INFO:43.5%, step:3199, perplexity: 42.076, speed: 27659 words
# 06:21:20 INFO:44.8%, step:3299, perplexity: 42.088, speed: 27677 words
# 06:21:21 INFO:46.2%, step:3399, perplexity: 42.099, speed: 27673 words
# 06:21:23 INFO:47.5%, step:3499, perplexity: 42.109, speed: 27669 words
# 06:21:24 INFO:48.9%, step:3599, perplexity: 42.120, speed: 27685 words
# 06:21:26 INFO:50.3%, step:3699, perplexity: 42.130, speed: 27707 words
# 06:21:27 INFO:51.6%, step:3799, perplexity: 42.140, speed: 27727 words
# 06:21:29 INFO:53.0%, step:3899, perplexity: 42.151, speed: 27743 words
# 06:21:30 INFO:54.3%, step:3999, perplexity: 42.161, speed: 27763 words
# 06:21:31 INFO:55.7%, step:4099, perplexity: 42.171, speed: 27773 words
# 06:21:33 INFO:57.0%, step:4199, perplexity: 42.180, speed: 27787 words
# 06:21:34 INFO:58.4%, step:4299, perplexity: 42.186, speed: 27808 words
# 06:21:36 INFO:59.8%, step:4399, perplexity: 42.191, speed: 27828 words
# 06:21:37 INFO:61.1%, step:4499, perplexity: 42.196, speed: 27845 words
# 06:21:38 INFO:62.5%, step:4599, perplexity: 42.201, speed: 27860 words
# 06:21:40 INFO:63.8%, step:4699, perplexity: 42.203, speed: 27875 words
# 06:21:41 INFO:65.2%, step:4799, perplexity: 42.206, speed: 27891 words
# 06:21:43 INFO:66.5%, step:4899, perplexity: 42.208, speed: 27910 words
# 06:21:44 INFO:67.9%, step:4999, perplexity: 42.209, speed: 27922 words
# 06:21:45 INFO:69.3%, step:5099, perplexity: 42.211, speed: 27931 words
# 06:21:47 INFO:70.6%, step:5199, perplexity: 42.214, speed: 27944 words
# 06:21:48 INFO:72.0%, step:5299, perplexity: 42.216, speed: 27959 words
# 06:21:50 INFO:73.3%, step:5399, perplexity: 42.218, speed: 27970 words
# 06:21:51 INFO:74.7%, step:5499, perplexity: 42.220, speed: 27979 words
# 06:21:52 INFO:76.1%, step:5599, perplexity: 42.222, speed: 27992 words
# 06:21:54 INFO:77.4%, step:5699, perplexity: 42.224, speed: 28002 words
# 06:21:55 INFO:78.8%, step:5799, perplexity: 42.225, speed: 27997 words
# 06:21:57 INFO:80.1%, step:5899, perplexity: 42.226, speed: 28001 words
# 06:21:58 INFO:81.5%, step:5999, perplexity: 42.227, speed: 28011 words
# 06:21:59 INFO:82.8%, step:6099, perplexity: 42.227, speed: 28018 words
# 06:22:01 INFO:84.2%, step:6199, perplexity: 42.226, speed: 28027 words
# 06:22:02 INFO:85.6%, step:6299, perplexity: 42.225, speed: 28035 words
# 06:22:04 INFO:86.9%, step:6399, perplexity: 42.224, speed: 28043 words
# 06:22:05 INFO:88.3%, step:6499, perplexity: 42.224, speed: 28051 words
# 06:22:06 INFO:89.6%, step:6599, perplexity: 42.223, speed: 28056 words
# 06:22:08 INFO:91.0%, step:6699, perplexity: 42.222, speed: 28065 words
# 06:22:09 INFO:92.4%, step:6799, perplexity: 42.219, speed: 28074 words
# 06:22:11 INFO:93.7%, step:6899, perplexity: 42.216, speed: 28080 words
# 06:22:12 INFO:95.1%, step:6999, perplexity: 42.213, speed: 28087 words
# 06:22:13 INFO:96.4%, step:7099, perplexity: 42.209, speed: 28093 words
# 06:22:15 INFO:97.8%, step:7199, perplexity: 42.205, speed: 28096 words
# 06:22:16 INFO:99.1%, step:7299, perplexity: 42.199, speed: 28103 words
# 06:22:17 INFO:Perplexity: 41.710, speed: 28105 words per sec
# 06:22:17 INFO:Latest model saved in demo_model/save_model/model-36815
#
# 06:22:17 INFO:Evaluate on validation set
# 06:22:17 INFO:epoch_size: 409
# 06:22:17 INFO:data_size: 20
# 06:22:17 INFO:num_unrollings: 20
# 06:22:17 INFO:batch_size: 20
# 06:22:18 INFO:24.4%, step:99, perplexity: 66.751, speed: 67548 words
# 06:22:19 INFO:48.9%, step:199, perplexity: 67.604, speed: 69373 words
# 06:22:19 INFO:73.3%, step:299, perplexity: 67.625, speed: 69910 words
# 06:22:20 INFO:97.8%, step:399, perplexity: 67.436, speed: 70672 words
# 06:22:20 INFO:Perplexity: 66.650, speed: 70680 words per sec
# 06:22:20 INFO:Best model is saved in demo_model/best_model/model-36815
# 06:22:20 INFO:Best validation ppl is 66.649796
#
# 06:22:20 INFO:=================== Epoch 5 ===================
#
# 06:22:20 INFO:Training on training set
# 06:22:20 INFO:epoch_size: 7363
# 06:22:20 INFO:data_size: 20
# 06:22:20 INFO:num_unrollings: 20
# 06:22:20 INFO:batch_size: 20
# 06:22:22 INFO:1.4%, step:99, perplexity: 40.377, speed: 28035 words
# 06:22:23 INFO:2.7%, step:199, perplexity: 41.015, speed: 28193 words
# 06:22:24 INFO:4.1%, step:299, perplexity: 41.590, speed: 28052 words
# 06:22:26 INFO:5.4%, step:399, perplexity: 41.692, speed: 28102 words
# 06:22:27 INFO:6.8%, step:499, perplexity: 41.590, speed: 28091 words
# 06:22:29 INFO:8.1%, step:599, perplexity: 41.537, speed: 28128 words
# 06:22:30 INFO:9.5%, step:699, perplexity: 41.468, speed: 28084 words
# 06:22:32 INFO:10.9%, step:799, perplexity: 41.399, speed: 27958 words
# 06:22:33 INFO:12.2%, step:899, perplexity: 41.359, speed: 27857 words
# 06:22:34 INFO:13.6%, step:999, perplexity: 41.293, speed: 27876 words
# 06:22:36 INFO:14.9%, step:1099, perplexity: 41.210, speed: 27905 words
# 06:22:37 INFO:16.3%, step:1199, perplexity: 41.130, speed: 27869 words
# 06:22:39 INFO:17.7%, step:1299, perplexity: 41.049, speed: 27812 words
# 06:22:40 INFO:19.0%, step:1399, perplexity: 40.976, speed: 27769 words
# 06:22:42 INFO:20.4%, step:1499, perplexity: 40.909, speed: 27772 words
# 06:22:43 INFO:21.7%, step:1599, perplexity: 40.844, speed: 27800 words
# 06:22:45 INFO:23.1%, step:1699, perplexity: 40.791, speed: 27826 words
# 06:22:46 INFO:24.4%, step:1799, perplexity: 40.756, speed: 27860 words
# 06:22:47 INFO:25.8%, step:1899, perplexity: 40.729, speed: 27887 words
# 06:22:49 INFO:27.2%, step:1999, perplexity: 40.703, speed: 27914 words
# 06:22:50 INFO:28.5%, step:2099, perplexity: 40.683, speed: 27946 words
# 06:22:52 INFO:29.9%, step:2199, perplexity: 40.665, speed: 27961 words
# 06:22:53 INFO:31.2%, step:2299, perplexity: 40.655, speed: 27992 words
# 06:22:54 INFO:32.6%, step:2399, perplexity: 40.655, speed: 28016 words
# 06:22:56 INFO:34.0%, step:2499, perplexity: 40.658, speed: 28018 words
# 06:22:57 INFO:35.3%, step:2599, perplexity: 40.661, speed: 28019 words
# 06:22:59 INFO:36.7%, step:2699, perplexity: 40.670, speed: 28003 words
# 06:23:00 INFO:38.0%, step:2799, perplexity: 40.681, speed: 28008 words
# 06:23:02 INFO:39.4%, step:2899, perplexity: 40.694, speed: 28015 words
# 06:23:03 INFO:40.7%, step:2999, perplexity: 40.708, speed: 28029 words
# 06:23:04 INFO:42.1%, step:3099, perplexity: 40.723, speed: 28029 words
# 06:23:06 INFO:43.5%, step:3199, perplexity: 40.738, speed: 28032 words
# 06:23:07 INFO:44.8%, step:3299, perplexity: 40.751, speed: 28044 words
# 06:23:09 INFO:46.2%, step:3399, perplexity: 40.764, speed: 28060 words
# 06:23:10 INFO:47.5%, step:3499, perplexity: 40.776, speed: 28076 words
# 06:23:11 INFO:48.9%, step:3599, perplexity: 40.789, speed: 28089 words
# 06:23:13 INFO:50.3%, step:3699, perplexity: 40.801, speed: 28104 words
# 06:23:14 INFO:51.6%, step:3799, perplexity: 40.813, speed: 28110 words
# 06:23:16 INFO:53.0%, step:3899, perplexity: 40.826, speed: 28114 words
# 06:23:17 INFO:54.3%, step:3999, perplexity: 40.838, speed: 28119 words
# 06:23:18 INFO:55.7%, step:4099, perplexity: 40.850, speed: 28127 words
# 06:23:20 INFO:57.0%, step:4199, perplexity: 40.860, speed: 28140 words
# 06:23:21 INFO:58.4%, step:4299, perplexity: 40.868, speed: 28148 words
# 06:23:23 INFO:59.8%, step:4399, perplexity: 40.875, speed: 28156 words
# 06:23:24 INFO:61.1%, step:4499, perplexity: 40.882, speed: 28167 words
# 06:23:25 INFO:62.5%, step:4599, perplexity: 40.888, speed: 28177 words
# 06:23:27 INFO:63.8%, step:4699, perplexity: 40.893, speed: 28185 words
# 06:23:28 INFO:65.2%, step:4799, perplexity: 40.897, speed: 28195 words
# 06:23:30 INFO:66.5%, step:4899, perplexity: 40.901, speed: 28199 words
# 06:23:31 INFO:67.9%, step:4999, perplexity: 40.904, speed: 28207 words
# 06:23:32 INFO:69.3%, step:5099, perplexity: 40.908, speed: 28217 words
# 06:23:34 INFO:70.6%, step:5199, perplexity: 40.912, speed: 28223 words
# 06:23:35 INFO:72.0%, step:5299, perplexity: 40.916, speed: 28233 words
# 06:23:37 INFO:73.3%, step:5399, perplexity: 40.920, speed: 28237 words
# 06:23:38 INFO:74.7%, step:5499, perplexity: 40.923, speed: 28239 words
# 06:23:39 INFO:76.1%, step:5599, perplexity: 40.927, speed: 28243 words
# 06:23:41 INFO:77.4%, step:5699, perplexity: 40.930, speed: 28237 words
# 06:23:42 INFO:78.8%, step:5799, perplexity: 40.933, speed: 28234 words
# 06:23:44 INFO:80.1%, step:5899, perplexity: 40.936, speed: 28236 words
# 06:23:45 INFO:81.5%, step:5999, perplexity: 40.938, speed: 28237 words
# 06:23:46 INFO:82.8%, step:6099, perplexity: 40.940, speed: 28243 words
# 06:23:48 INFO:84.2%, step:6199, perplexity: 40.941, speed: 28251 words
# 06:23:49 INFO:85.6%, step:6299, perplexity: 40.941, speed: 28248 words
# 06:23:51 INFO:86.9%, step:6399, perplexity: 40.942, speed: 28249 words
# 06:23:52 INFO:88.3%, step:6499, perplexity: 40.943, speed: 28251 words
# 06:23:54 INFO:89.6%, step:6599, perplexity: 40.944, speed: 28255 words
# 06:23:55 INFO:91.0%, step:6699, perplexity: 40.944, speed: 28255 words
# 06:23:56 INFO:92.4%, step:6799, perplexity: 40.943, speed: 28257 words
# 06:23:58 INFO:93.7%, step:6899, perplexity: 40.942, speed: 28258 words
# 06:23:59 INFO:95.1%, step:6999, perplexity: 40.940, speed: 28263 words
# 06:24:01 INFO:96.4%, step:7099, perplexity: 40.938, speed: 28268 words
# 06:24:02 INFO:97.8%, step:7199, perplexity: 40.934, speed: 28271 words
# 06:24:03 INFO:99.1%, step:7299, perplexity: 40.931, speed: 28277 words
# 06:24:04 INFO:Perplexity: 40.556, speed: 28277 words per sec
# 06:24:05 INFO:Latest model saved in demo_model/save_model/model-44178
#
# 06:24:05 INFO:Evaluate on validation set
# 06:24:05 INFO:epoch_size: 409
# 06:24:05 INFO:data_size: 20
# 06:24:05 INFO:num_unrollings: 20
# 06:24:05 INFO:batch_size: 20
# 06:24:05 INFO:24.4%, step:99, perplexity: 68.130, speed: 66550 words
# 06:24:06 INFO:48.9%, step:199, perplexity: 68.581, speed: 68925 words
# 06:24:06 INFO:73.3%, step:299, perplexity: 68.402, speed: 70087 words
# 06:24:07 INFO:97.8%, step:399, perplexity: 68.154, speed: 70538 words
# 06:24:07 INFO:Perplexity: 67.200, speed: 70604 words per sec
# 06:24:07 INFO:Decay the learning rate: 0.0025
# 06:24:07 INFO:Best model is saved in demo_model/best_model/model-36815
# 06:24:07 INFO:Best validation ppl is 66.649796
#
# 06:24:07 INFO:=================== Epoch 6 ===================
#
# 06:24:07 INFO:Training on training set
# 06:24:07 INFO:epoch_size: 7363
# 06:24:07 INFO:data_size: 20
# 06:24:07 INFO:num_unrollings: 20
# 06:24:07 INFO:batch_size: 20
# 06:24:08 INFO:1.4%, step:99, perplexity: 39.110, speed: 27537 words
# 06:24:10 INFO:2.7%, step:199, perplexity: 39.628, speed: 27887 words
# 06:24:11 INFO:4.1%, step:299, perplexity: 40.131, speed: 27843 words
# 06:24:13 INFO:5.4%, step:399, perplexity: 40.207, speed: 27881 words
# 06:24:14 INFO:6.8%, step:499, perplexity: 40.083, speed: 27919 words
# 06:24:16 INFO:8.1%, step:599, perplexity: 39.999, speed: 27935 words
# 06:24:17 INFO:9.5%, step:699, perplexity: 39.896, speed: 27974 words
# 06:24:18 INFO:10.9%, step:799, perplexity: 39.791, speed: 27982 words
# 06:24:20 INFO:12.2%, step:899, perplexity: 39.713, speed: 27989 words
# 06:24:21 INFO:13.6%, step:999, perplexity: 39.611, speed: 28011 words
# 06:24:23 INFO:14.9%, step:1099, perplexity: 39.495, speed: 28027 words
# 06:24:24 INFO:16.3%, step:1199, perplexity: 39.384, speed: 27910 words
# 06:24:26 INFO:17.7%, step:1299, perplexity: 39.274, speed: 27830 words
# 06:24:27 INFO:19.0%, step:1399, perplexity: 39.171, speed: 27831 words
# 06:24:29 INFO:20.4%, step:1499, perplexity: 39.074, speed: 27860 words
# 06:24:30 INFO:21.7%, step:1599, perplexity: 38.982, speed: 27873 words
# 06:24:31 INFO:23.1%, step:1699, perplexity: 38.902, speed: 27862 words
# 06:24:33 INFO:24.4%, step:1799, perplexity: 38.841, speed: 27865 words
# 06:24:34 INFO:25.8%, step:1899, perplexity: 38.788, speed: 27908 words
# 06:24:36 INFO:27.2%, step:1999, perplexity: 38.738, speed: 27936 words
# 06:24:37 INFO:28.5%, step:2099, perplexity: 38.693, speed: 27963 words
# 06:24:38 INFO:29.9%, step:2199, perplexity: 38.653, speed: 27994 words
# 06:24:40 INFO:31.2%, step:2299, perplexity: 38.619, speed: 28021 words
# 06:24:41 INFO:32.6%, step:2399, perplexity: 38.596, speed: 28044 words
# 06:24:43 INFO:34.0%, step:2499, perplexity: 38.576, speed: 28051 words
# 06:24:44 INFO:35.3%, step:2599, perplexity: 38.557, speed: 28062 words
# 06:24:45 INFO:36.7%, step:2699, perplexity: 38.543, speed: 28086 words
# 06:24:47 INFO:38.0%, step:2799, perplexity: 38.532, speed: 28103 words
# 06:24:48 INFO:39.4%, step:2899, perplexity: 38.524, speed: 28116 words
# 06:24:50 INFO:40.7%, step:2999, perplexity: 38.516, speed: 28119 words
# 06:24:51 INFO:42.1%, step:3099, perplexity: 38.510, speed: 28110 words
# 06:24:53 INFO:43.5%, step:3199, perplexity: 38.505, speed: 28108 words
# 06:24:54 INFO:44.8%, step:3299, perplexity: 38.499, speed: 28121 words
# 06:24:55 INFO:46.2%, step:3399, perplexity: 38.492, speed: 28131 words
# 06:24:57 INFO:47.5%, step:3499, perplexity: 38.485, speed: 28123 words
# 06:24:58 INFO:48.9%, step:3599, perplexity: 38.479, speed: 28097 words
# 06:25:00 INFO:50.3%, step:3699, perplexity: 38.472, speed: 28091 words
# 06:25:01 INFO:51.6%, step:3799, perplexity: 38.466, speed: 28100 words
# 06:25:02 INFO:53.0%, step:3899, perplexity: 38.460, speed: 28094 words
# 06:25:04 INFO:54.3%, step:3999, perplexity: 38.454, speed: 28094 words
# 06:25:05 INFO:55.7%, step:4099, perplexity: 38.449, speed: 28108 words
# 06:25:07 INFO:57.0%, step:4199, perplexity: 38.442, speed: 28117 words
# 06:25:08 INFO:58.4%, step:4299, perplexity: 38.433, speed: 28130 words
# 06:25:10 INFO:59.8%, step:4399, perplexity: 38.424, speed: 28141 words
# 06:25:11 INFO:61.1%, step:4499, perplexity: 38.415, speed: 28155 words
# 06:25:12 INFO:62.5%, step:4599, perplexity: 38.405, speed: 28167 words
# 06:25:14 INFO:63.8%, step:4699, perplexity: 38.394, speed: 28178 words
# 06:25:15 INFO:65.2%, step:4799, perplexity: 38.383, speed: 28183 words
# 06:25:16 INFO:66.5%, step:4899, perplexity: 38.371, speed: 28191 words
# 06:25:18 INFO:67.9%, step:4999, perplexity: 38.360, speed: 28198 words
# 06:25:19 INFO:69.3%, step:5099, perplexity: 38.348, speed: 28205 words
# 06:25:21 INFO:70.6%, step:5199, perplexity: 38.338, speed: 28212 words
# 06:25:22 INFO:72.0%, step:5299, perplexity: 38.327, speed: 28217 words
# 06:25:24 INFO:73.3%, step:5399, perplexity: 38.316, speed: 28223 words
# 06:25:25 INFO:74.7%, step:5499, perplexity: 38.306, speed: 28224 words
# 06:25:26 INFO:76.1%, step:5599, perplexity: 38.295, speed: 28229 words
# 06:25:28 INFO:77.4%, step:5699, perplexity: 38.284, speed: 28237 words
# 06:25:29 INFO:78.8%, step:5799, perplexity: 38.273, speed: 28237 words
# 06:25:31 INFO:80.1%, step:5899, perplexity: 38.262, speed: 28242 words
# 06:25:32 INFO:81.5%, step:5999, perplexity: 38.251, speed: 28242 words
# 06:25:33 INFO:82.8%, step:6099, perplexity: 38.239, speed: 28243 words
# 06:25:35 INFO:84.2%, step:6199, perplexity: 38.226, speed: 28247 words
# 06:25:36 INFO:85.6%, step:6299, perplexity: 38.213, speed: 28253 words
# 06:25:38 INFO:86.9%, step:6399, perplexity: 38.201, speed: 28256 words
# 06:25:39 INFO:88.3%, step:6499, perplexity: 38.189, speed: 28261 words
# 06:25:40 INFO:89.6%, step:6599, perplexity: 38.177, speed: 28262 words
# 06:25:42 INFO:91.0%, step:6699, perplexity: 38.164, speed: 28267 words
# 06:25:43 INFO:92.4%, step:6799, perplexity: 38.150, speed: 28275 words
# 06:25:45 INFO:93.7%, step:6899, perplexity: 38.136, speed: 28279 words
# 06:25:46 INFO:95.1%, step:6999, perplexity: 38.122, speed: 28284 words
# 06:25:47 INFO:96.4%, step:7099, perplexity: 38.107, speed: 28280 words
# 06:25:49 INFO:97.8%, step:7199, perplexity: 38.091, speed: 28281 words
# 06:25:50 INFO:99.1%, step:7299, perplexity: 38.075, speed: 28286 words
# 06:25:51 INFO:Perplexity: 36.813, speed: 28288 words per sec
# 06:25:51 INFO:Latest model saved in demo_model/save_model/model-51541
#
# 06:25:51 INFO:Evaluate on validation set
# 06:25:51 INFO:epoch_size: 409
# 06:25:51 INFO:data_size: 20
# 06:25:51 INFO:num_unrollings: 20
# 06:25:51 INFO:batch_size: 20
# 06:25:52 INFO:24.4%, step:99, perplexity: 63.760, speed: 69852 words
# 06:25:53 INFO:48.9%, step:199, perplexity: 64.309, speed: 70743 words
# 06:25:53 INFO:73.3%, step:299, perplexity: 64.243, speed: 71381 words
# 06:25:54 INFO:97.8%, step:399, perplexity: 64.079, speed: 71134 words
# 06:25:54 INFO:Perplexity: 63.369, speed: 71042 words per sec
# 06:25:54 INFO:Best model is saved in demo_model/best_model/model-51541
# 06:25:54 INFO:Best validation ppl is 63.368584
#
# 06:25:54 INFO:=================== Epoch 7 ===================
#
# 06:25:54 INFO:Training on training set
# 06:25:54 INFO:epoch_size: 7363
# 06:25:54 INFO:data_size: 20
# 06:25:54 INFO:num_unrollings: 20
# 06:25:54 INFO:batch_size: 20
# 06:25:56 INFO:1.4%, step:99, perplexity: 35.278, speed: 28162 words
# 06:25:57 INFO:2.7%, step:199, perplexity: 35.903, speed: 28158 words
# 06:25:58 INFO:4.1%, step:299, perplexity: 36.455, speed: 28045 words
# 06:26:00 INFO:5.4%, step:399, perplexity: 36.605, speed: 27822 words
# 06:26:01 INFO:6.8%, step:499, perplexity: 36.564, speed: 27743 words
# 06:26:03 INFO:8.1%, step:599, perplexity: 36.550, speed: 27832 words
# 06:26:04 INFO:9.5%, step:699, perplexity: 36.512, speed: 27850 words
# 06:26:06 INFO:10.9%, step:799, perplexity: 36.466, speed: 27919 words
# 06:26:07 INFO:12.2%, step:899, perplexity: 36.440, speed: 27900 words
# 06:26:08 INFO:13.6%, step:999, perplexity: 36.391, speed: 27882 words
# 06:26:10 INFO:14.9%, step:1099, perplexity: 36.326, speed: 27874 words
# 06:26:11 INFO:16.3%, step:1199, perplexity: 36.262, speed: 27856 words
# 06:26:13 INFO:17.7%, step:1299, perplexity: 36.196, speed: 27836 words
# 06:26:14 INFO:19.0%, step:1399, perplexity: 36.134, speed: 27847 words
# 06:26:16 INFO:20.4%, step:1499, perplexity: 36.076, speed: 27858 words
# 06:26:17 INFO:21.7%, step:1599, perplexity: 36.020, speed: 27782 words
# 06:26:19 INFO:23.1%, step:1699, perplexity: 35.973, speed: 27763 words
# 06:26:20 INFO:24.4%, step:1799, perplexity: 35.942, speed: 27796 words
# 06:26:21 INFO:25.8%, step:1899, perplexity: 35.917, speed: 27825 words
# 06:26:23 INFO:27.2%, step:1999, perplexity: 35.894, speed: 27842 words
# 06:26:24 INFO:28.5%, step:2099, perplexity: 35.876, speed: 27859 words
# 06:26:26 INFO:29.9%, step:2199, perplexity: 35.860, speed: 27880 words
# 06:26:27 INFO:31.2%, step:2299, perplexity: 35.849, speed: 27911 words
# 06:26:28 INFO:32.6%, step:2399, perplexity: 35.848, speed: 27935 words
# 06:26:30 INFO:34.0%, step:2499, perplexity: 35.849, speed: 27959 words
# 06:26:31 INFO:35.3%, step:2599, perplexity: 35.850, speed: 27970 words
# 06:26:33 INFO:36.7%, step:2699, perplexity: 35.855, speed: 27991 words
# 06:26:34 INFO:38.0%, step:2799, perplexity: 35.862, speed: 28001 words
# 06:26:36 INFO:39.4%, step:2899, perplexity: 35.871, speed: 28018 words
# 06:26:37 INFO:40.7%, step:2999, perplexity: 35.881, speed: 28033 words
# 06:26:38 INFO:42.1%, step:3099, perplexity: 35.892, speed: 28047 words
# 06:26:40 INFO:43.5%, step:3199, perplexity: 35.902, speed: 28060 words
# 06:26:41 INFO:44.8%, step:3299, perplexity: 35.912, speed: 28074 words
# 06:26:43 INFO:46.2%, step:3399, perplexity: 35.920, speed: 28085 words
# 06:26:44 INFO:47.5%, step:3499, perplexity: 35.929, speed: 28095 words
# 06:26:45 INFO:48.9%, step:3599, perplexity: 35.937, speed: 28106 words
# 06:26:47 INFO:50.3%, step:3699, perplexity: 35.945, speed: 28122 words
# 06:26:48 INFO:51.6%, step:3799, perplexity: 35.952, speed: 28135 words
# 06:26:50 INFO:53.0%, step:3899, perplexity: 35.960, speed: 28143 words
# 06:26:51 INFO:54.3%, step:3999, perplexity: 35.968, speed: 28154 words
# 06:26:52 INFO:55.7%, step:4099, perplexity: 35.975, speed: 28157 words
# 06:26:54 INFO:57.0%, step:4199, perplexity: 35.981, speed: 28165 words
# 06:26:55 INFO:58.4%, step:4299, perplexity: 35.985, speed: 28176 words
# 06:26:57 INFO:59.8%, step:4399, perplexity: 35.989, speed: 28161 words
# 06:26:58 INFO:61.1%, step:4499, perplexity: 35.992, speed: 28164 words
# 06:26:59 INFO:62.5%, step:4599, perplexity: 35.994, speed: 28159 words
# 06:27:01 INFO:63.8%, step:4699, perplexity: 35.995, speed: 28160 words
# 06:27:02 INFO:65.2%, step:4799, perplexity: 35.995, speed: 28163 words
# 06:27:04 INFO:66.5%, step:4899, perplexity: 35.996, speed: 28160 words
# 06:27:05 INFO:67.9%, step:4999, perplexity: 35.995, speed: 28166 words
# 06:27:07 INFO:69.3%, step:5099, perplexity: 35.995, speed: 28173 words
# 06:27:08 INFO:70.6%, step:5199, perplexity: 35.995, speed: 28178 words
# 06:27:09 INFO:72.0%, step:5299, perplexity: 35.995, speed: 28176 words
# 06:27:11 INFO:73.3%, step:5399, perplexity: 35.995, speed: 28177 words
# 06:27:12 INFO:74.7%, step:5499, perplexity: 35.995, speed: 28181 words
# 06:27:14 INFO:76.1%, step:5599, perplexity: 35.995, speed: 28189 words
# 06:27:15 INFO:77.4%, step:5699, perplexity: 35.994, speed: 28193 words
# 06:27:16 INFO:78.8%, step:5799, perplexity: 35.993, speed: 28200 words
# ...
# 07:38:32 INFO:58.4%, step:4299, perplexity: 29.979, speed: 28396 words
# 07:38:33 INFO:59.8%, step:4399, perplexity: 29.984, speed: 28395 words
# 07:38:35 INFO:61.1%, step:4499, perplexity: 29.987, speed: 28407 words
# 07:38:36 INFO:62.5%, step:4599, perplexity: 29.991, speed: 28397 words
# 07:38:37 INFO:63.8%, step:4699, perplexity: 29.993, speed: 28393 words
# 07:38:39 INFO:65.2%, step:4799, perplexity: 29.995, speed: 28392 words
# 07:38:40 INFO:66.5%, step:4899, perplexity: 29.996, speed: 28388 words
# 07:38:42 INFO:67.9%, step:4999, perplexity: 29.997, speed: 28383 words
# 07:38:43 INFO:69.3%, step:5099, perplexity: 29.997, speed: 28381 words
# 07:38:45 INFO:70.6%, step:5199, perplexity: 29.999, speed: 28369 words
# 07:38:46 INFO:72.0%, step:5299, perplexity: 29.999, speed: 28372 words
# 07:38:47 INFO:73.3%, step:5399, perplexity: 30.000, speed: 28375 words
# 07:38:49 INFO:74.7%, step:5499, perplexity: 30.000, speed: 28380 words
# 07:38:50 INFO:76.1%, step:5599, perplexity: 30.000, speed: 28387 words
# 07:38:52 INFO:77.4%, step:5699, perplexity: 30.000, speed: 28391 words
# 07:38:53 INFO:78.8%, step:5799, perplexity: 30.000, speed: 28393 words
# 07:38:54 INFO:80.1%, step:5899, perplexity: 29.999, speed: 28396 words
# 07:38:56 INFO:81.5%, step:5999, perplexity: 29.999, speed: 28395 words
# 07:38:57 INFO:82.8%, step:6099, perplexity: 29.997, speed: 28387 words
# 07:38:59 INFO:84.2%, step:6199, perplexity: 29.995, speed: 28386 words
# 07:39:00 INFO:85.6%, step:6299, perplexity: 29.992, speed: 28391 words
# 07:39:01 INFO:86.9%, step:6399, perplexity: 29.989, speed: 28395 words
# 07:39:03 INFO:88.3%, step:6499, perplexity: 29.987, speed: 28395 words
# 07:39:04 INFO:89.6%, step:6599, perplexity: 29.984, speed: 28394 words
# 07:39:06 INFO:91.0%, step:6699, perplexity: 29.980, speed: 28399 words
# 07:39:07 INFO:92.4%, step:6799, perplexity: 29.976, speed: 28407 words
# 07:39:08 INFO:93.7%, step:6899, perplexity: 29.971, speed: 28411 words
# 07:39:10 INFO:95.1%, step:6999, perplexity: 29.965, speed: 28408 words
# 07:39:11 INFO:96.4%, step:7099, perplexity: 29.960, speed: 28410 words
# 07:39:13 INFO:97.8%, step:7199, perplexity: 29.953, speed: 28409 words
# 07:39:14 INFO:99.1%, step:7299, perplexity: 29.946, speed: 28400 words
# 07:39:15 INFO:Perplexity: 29.382, speed: 28402 words per sec
# 07:39:15 INFO:Latest model saved in demo_model/save_model/model-353424
#
# 07:39:15 INFO:Evaluate on validation set
# 07:39:15 INFO:epoch_size: 409
# 07:39:15 INFO:data_size: 20
# 07:39:15 INFO:num_unrollings: 20
# 07:39:15 INFO:batch_size: 20
# 07:39:16 INFO:24.4%, step:99, perplexity: 60.408, speed: 68857 words
# 07:39:16 INFO:48.9%, step:199, perplexity: 60.959, speed: 71351 words
# 07:39:17 INFO:73.3%, step:299, perplexity: 60.975, speed: 71955 words
# 07:39:18 INFO:97.8%, step:399, perplexity: 60.899, speed: 72071 words
# 07:39:18 INFO:Perplexity: 60.461, speed: 72002 words per sec
# 07:39:18 INFO:Best model is saved in demo_model/best_model/model-353424
# 07:39:18 INFO:Best validation ppl is 60.460526
#
# 07:39:18 INFO:=================== Epoch 48 ===================
#
# 07:39:18 INFO:Training on training set
# 07:39:18 INFO:epoch_size: 7363
# 07:39:18 INFO:data_size: 20
# 07:39:18 INFO:num_unrollings: 20
# 07:39:18 INFO:batch_size: 20
# 07:39:19 INFO:1.4%, step:99, perplexity: 28.722, speed: 27572 words
# 07:39:21 INFO:2.7%, step:199, perplexity: 29.418, speed: 28086 words
# 07:39:22 INFO:4.1%, step:299, perplexity: 29.963, speed: 27999 words
# 07:39:24 INFO:5.4%, step:399, perplexity: 30.175, speed: 28070 words
# 07:39:25 INFO:6.8%, step:499, perplexity: 30.213, speed: 28151 words
# 07:39:26 INFO:8.1%, step:599, perplexity: 30.248, speed: 28190 words
# 07:39:28 INFO:9.5%, step:699, perplexity: 30.253, speed: 28215 words
# 07:39:29 INFO:10.9%, step:799, perplexity: 30.240, speed: 28236 words
# 07:39:31 INFO:12.2%, step:899, perplexity: 30.235, speed: 28237 words
# 07:39:32 INFO:13.6%, step:999, perplexity: 30.209, speed: 28211 words
# 07:39:33 INFO:14.9%, step:1099, perplexity: 30.170, speed: 28225 words
# 07:39:35 INFO:16.3%, step:1199, perplexity: 30.128, speed: 28248 words
# 07:39:36 INFO:17.7%, step:1299, perplexity: 30.083, speed: 28160 words
# 07:39:38 INFO:19.0%, step:1399, perplexity: 30.039, speed: 28137 words
# 07:39:39 INFO:20.4%, step:1499, perplexity: 29.997, speed: 28154 words
# 07:39:41 INFO:21.7%, step:1599, perplexity: 29.956, speed: 28185 words
# 07:39:42 INFO:23.1%, step:1699, perplexity: 29.920, speed: 28218 words
# 07:39:43 INFO:24.4%, step:1799, perplexity: 29.897, speed: 28236 words
# 07:39:45 INFO:25.8%, step:1899, perplexity: 29.879, speed: 28262 words
# 07:39:46 INFO:27.2%, step:1999, perplexity: 29.862, speed: 28281 words
# 07:39:48 INFO:28.5%, step:2099, perplexity: 29.850, speed: 28305 words
# 07:39:49 INFO:29.9%, step:2199, perplexity: 29.839, speed: 28310 words
# 07:39:50 INFO:31.2%, step:2299, perplexity: 29.833, speed: 28307 words
# 07:39:52 INFO:32.6%, step:2399, perplexity: 29.834, speed: 28313 words
# 07:39:53 INFO:34.0%, step:2499, perplexity: 29.836, speed: 28302 words
# 07:39:55 INFO:35.3%, step:2599, perplexity: 29.839, speed: 28306 words
# 07:39:56 INFO:36.7%, step:2699, perplexity: 29.845, speed: 28308 words
# 07:39:57 INFO:38.0%, step:2799, perplexity: 29.852, speed: 28318 words
# 07:39:59 INFO:39.4%, step:2899, perplexity: 29.861, speed: 28321 words
# 07:40:00 INFO:40.7%, step:2999, perplexity: 29.871, speed: 28323 words
# 07:40:02 INFO:42.1%, step:3099, perplexity: 29.881, speed: 28307 words
# 07:40:03 INFO:43.5%, step:3199, perplexity: 29.892, speed: 28321 words
# 07:40:04 INFO:44.8%, step:3299, perplexity: 29.901, speed: 28327 words
# 07:40:06 INFO:46.2%, step:3399, perplexity: 29.910, speed: 28329 words
# 07:40:07 INFO:47.5%, step:3499, perplexity: 29.918, speed: 28325 words
# 07:40:09 INFO:48.9%, step:3599, perplexity: 29.927, speed: 28330 words
# 07:40:10 INFO:50.3%, step:3699, perplexity: 29.935, speed: 28333 words
# 07:40:12 INFO:51.6%, step:3799, perplexity: 29.943, speed: 28344 words
# 07:40:13 INFO:53.0%, step:3899, perplexity: 29.951, speed: 28341 words
# 07:40:14 INFO:54.3%, step:3999, perplexity: 29.959, speed: 28341 words
# 07:40:16 INFO:55.7%, step:4099, perplexity: 29.966, speed: 28337 words
# 07:40:17 INFO:57.0%, step:4199, perplexity: 29.973, speed: 28337 words
# 07:40:19 INFO:58.4%, step:4299, perplexity: 29.978, speed: 28341 words
# 07:40:20 INFO:59.8%, step:4399, perplexity: 29.982, speed: 28352 words
# 07:40:21 INFO:61.1%, step:4499, perplexity: 29.986, speed: 28347 words
# 07:40:23 INFO:62.5%, step:4599, perplexity: 29.989, speed: 28327 words
# 07:40:24 INFO:63.8%, step:4699, perplexity: 29.992, speed: 28335 words
# 07:40:26 INFO:65.2%, step:4799, perplexity: 29.993, speed: 28342 words
# 07:40:27 INFO:66.5%, step:4899, perplexity: 29.995, speed: 28349 words
# 07:40:28 INFO:67.9%, step:4999, perplexity: 29.995, speed: 28349 words
# 07:40:30 INFO:69.3%, step:5099, perplexity: 29.996, speed: 28351 words
# 07:40:31 INFO:70.6%, step:5199, perplexity: 29.997, speed: 28358 words
# 07:40:33 INFO:72.0%, step:5299, perplexity: 29.998, speed: 28364 words
# 07:40:34 INFO:73.3%, step:5399, perplexity: 29.999, speed: 28371 words
# 07:40:35 INFO:74.7%, step:5499, perplexity: 29.999, speed: 28374 words
# 07:40:37 INFO:76.1%, step:5599, perplexity: 29.999, speed: 28376 words
# 07:40:38 INFO:77.4%, step:5699, perplexity: 29.999, speed: 28380 words
# 07:40:40 INFO:78.8%, step:5799, perplexity: 29.998, speed: 28380 words
# 07:40:41 INFO:80.1%, step:5899, perplexity: 29.998, speed: 28389 words
# 07:40:42 INFO:81.5%, step:5999, perplexity: 29.997, speed: 28392 words
# 07:40:44 INFO:82.8%, step:6099, perplexity: 29.996, speed: 28394 words
# 07:40:45 INFO:84.2%, step:6199, perplexity: 29.994, speed: 28399 words
# 07:40:47 INFO:85.6%, step:6299, perplexity: 29.991, speed: 28404 words
# 07:40:48 INFO:86.9%, step:6399, perplexity: 29.988, speed: 28408 words
# 07:40:49 INFO:88.3%, step:6499, perplexity: 29.985, speed: 28411 words
# 07:40:51 INFO:89.6%, step:6599, perplexity: 29.983, speed: 28416 words
# 07:40:52 INFO:91.0%, step:6699, perplexity: 29.979, speed: 28418 words
# 07:40:54 INFO:92.4%, step:6799, perplexity: 29.974, speed: 28423 words
# 07:40:55 INFO:93.7%, step:6899, perplexity: 29.970, speed: 28424 words
# 07:40:56 INFO:95.1%, step:6999, perplexity: 29.964, speed: 28423 words
# 07:40:58 INFO:96.4%, step:7099, perplexity: 29.959, speed: 28424 words
# 07:40:59 INFO:97.8%, step:7199, perplexity: 29.952, speed: 28420 words
# 07:41:01 INFO:99.1%, step:7299, perplexity: 29.945, speed: 28424 words
# 07:41:02 INFO:Perplexity: 29.381, speed: 28423 words per sec
# 07:41:02 INFO:Latest model saved in demo_model/save_model/model-360787
#
# 07:41:02 INFO:Evaluate on validation set
# 07:41:02 INFO:epoch_size: 409
# 07:41:02 INFO:data_size: 20
# 07:41:02 INFO:num_unrollings: 20
# 07:41:02 INFO:batch_size: 20
# 07:41:03 INFO:24.4%, step:99, perplexity: 60.407, speed: 66053 words
# 07:41:03 INFO:48.9%, step:199, perplexity: 60.958, speed: 68519 words
# 07:41:04 INFO:73.3%, step:299, perplexity: 60.974, speed: 68794 words
# 07:41:04 INFO:97.8%, step:399, perplexity: 60.898, speed: 69621 words
# 07:41:04 INFO:Perplexity: 60.460, speed: 69683 words per sec
# 07:41:05 INFO:Best model is saved in demo_model/best_model/model-360787
# 07:41:05 INFO:Best validation ppl is 60.459866
#
# 07:41:05 INFO:=================== Epoch 49 ===================
#
# 07:41:05 INFO:Training on training set
# 07:41:05 INFO:epoch_size: 7363
# 07:41:05 INFO:data_size: 20
# 07:41:05 INFO:num_unrollings: 20
# 07:41:05 INFO:batch_size: 20
# 07:41:06 INFO:1.4%, step:99, perplexity: 28.720, speed: 28365 words
# 07:41:07 INFO:2.7%, step:199, perplexity: 29.416, speed: 28141 words
# 07:41:09 INFO:4.1%, step:299, perplexity: 29.962, speed: 28208 words
# 07:41:10 INFO:5.4%, step:399, perplexity: 30.173, speed: 28139 words
# 07:41:12 INFO:6.8%, step:499, perplexity: 30.211, speed: 28159 words
# 07:41:13 INFO:8.1%, step:599, perplexity: 30.247, speed: 28181 words
# 07:41:15 INFO:9.5%, step:699, perplexity: 30.252, speed: 28170 words
# 07:41:16 INFO:10.9%, step:799, perplexity: 30.238, speed: 28104 words
# 07:41:17 INFO:12.2%, step:899, perplexity: 30.234, speed: 28047 words
# 07:41:19 INFO:13.6%, step:999, perplexity: 30.208, speed: 27903 words
# 07:41:20 INFO:14.9%, step:1099, perplexity: 30.168, speed: 27928 words
# 07:41:22 INFO:16.3%, step:1199, perplexity: 30.127, speed: 27977 words
# 07:41:23 INFO:17.7%, step:1299, perplexity: 30.082, speed: 28014 words
# 07:41:25 INFO:19.0%, step:1399, perplexity: 30.038, speed: 28042 words
# 07:41:26 INFO:20.4%, step:1499, perplexity: 29.996, speed: 28074 words
# 07:41:27 INFO:21.7%, step:1599, perplexity: 29.954, speed: 28063 words
# 07:41:29 INFO:23.1%, step:1699, perplexity: 29.919, speed: 28072 words
# 07:41:30 INFO:24.4%, step:1799, perplexity: 29.896, speed: 28090 words
# 07:41:32 INFO:25.8%, step:1899, perplexity: 29.878, speed: 28121 words
# 07:41:33 INFO:27.2%, step:1999, perplexity: 29.861, speed: 28106 words
# 07:41:34 INFO:28.5%, step:2099, perplexity: 29.848, speed: 28123 words
# 07:41:36 INFO:29.9%, step:2199, perplexity: 29.838, speed: 28142 words
# 07:41:37 INFO:31.2%, step:2299, perplexity: 29.832, speed: 28165 words
# 07:41:39 INFO:32.6%, step:2399, perplexity: 29.832, speed: 28179 words
# 07:41:40 INFO:34.0%, step:2499, perplexity: 29.834, speed: 28204 words
# 07:41:41 INFO:35.3%, step:2599, perplexity: 29.837, speed: 28223 words
# 07:41:43 INFO:36.7%, step:2699, perplexity: 29.843, speed: 28223 words
# 07:41:44 INFO:38.0%, step:2799, perplexity: 29.851, speed: 28242 words
# 07:41:46 INFO:39.4%, step:2899, perplexity: 29.860, speed: 28257 words
# 07:41:47 INFO:40.7%, step:2999, perplexity: 29.870, speed: 28265 words
# 07:41:48 INFO:42.1%, step:3099, perplexity: 29.880, speed: 28280 words
# 07:41:50 INFO:43.5%, step:3199, perplexity: 29.890, speed: 28286 words
# 07:41:51 INFO:44.8%, step:3299, perplexity: 29.900, speed: 28292 words
# 07:41:53 INFO:46.2%, step:3399, perplexity: 29.908, speed: 28301 words
# 07:41:54 INFO:47.5%, step:3499, perplexity: 29.917, speed: 28313 words
# 07:41:55 INFO:48.9%, step:3599, perplexity: 29.925, speed: 28330 words
# 07:41:57 INFO:50.3%, step:3699, perplexity: 29.933, speed: 28323 words
# 07:41:58 INFO:51.6%, step:3799, perplexity: 29.941, speed: 28332 words
# 07:42:00 INFO:53.0%, step:3899, perplexity: 29.949, speed: 28342 words
# 07:42:01 INFO:54.3%, step:3999, perplexity: 29.957, speed: 28357 words
# 07:42:02 INFO:55.7%, step:4099, perplexity: 29.965, speed: 28365 words
# 07:42:04 INFO:57.0%, step:4199, perplexity: 29.972, speed: 28369 words
# 07:42:05 INFO:58.4%, step:4299, perplexity: 29.977, speed: 28381 words
# 07:42:07 INFO:59.8%, step:4399, perplexity: 29.981, speed: 28386 words
# 07:42:08 INFO:61.1%, step:4499, perplexity: 29.985, speed: 28397 words
# 07:42:09 INFO:62.5%, step:4599, perplexity: 29.988, speed: 28406 words
# 07:42:11 INFO:63.8%, step:4699, perplexity: 29.990, speed: 28410 words
# 07:42:12 INFO:65.2%, step:4799, perplexity: 29.992, speed: 28416 words
# 07:42:14 INFO:66.5%, step:4899, perplexity: 29.993, speed: 28419 words
# 07:42:15 INFO:67.9%, step:4999, perplexity: 29.994, speed: 28422 words
# 07:42:16 INFO:69.3%, step:5099, perplexity: 29.995, speed: 28414 words
# 07:42:18 INFO:70.6%, step:5199, perplexity: 29.996, speed: 28413 words
# 07:42:19 INFO:72.0%, step:5299, perplexity: 29.997, speed: 28407 words
# 07:42:21 INFO:73.3%, step:5399, perplexity: 29.997, speed: 28396 words
# 07:42:22 INFO:74.7%, step:5499, perplexity: 29.998, speed: 28393 words
# 07:42:23 INFO:76.1%, step:5599, perplexity: 29.998, speed: 28397 words
# 07:42:25 INFO:77.4%, step:5699, perplexity: 29.998, speed: 28389 words
# 07:42:26 INFO:78.8%, step:5799, perplexity: 29.997, speed: 28394 words
# 07:42:28 INFO:80.1%, step:5899, perplexity: 29.997, speed: 28397 words
# 07:42:29 INFO:81.5%, step:5999, perplexity: 29.996, speed: 28400 words
# 07:42:30 INFO:82.8%, step:6099, perplexity: 29.994, speed: 28403 words
# 07:42:32 INFO:84.2%, step:6199, perplexity: 29.992, speed: 28407 words
# 07:42:33 INFO:85.6%, step:6299, perplexity: 29.989, speed: 28414 words
# 07:42:35 INFO:86.9%, step:6399, perplexity: 29.987, speed: 28421 words
# 07:42:36 INFO:88.3%, step:6499, perplexity: 29.984, speed: 28426 words
# 07:42:38 INFO:89.6%, step:6599, perplexity: 29.981, speed: 28407 words
# 07:42:39 INFO:91.0%, step:6699, perplexity: 29.978, speed: 28395 words
# 07:42:40 INFO:92.4%, step:6799, perplexity: 29.973, speed: 28398 words
# 07:42:42 INFO:93.7%, step:6899, perplexity: 29.968, speed: 28398 words
# 07:42:43 INFO:95.1%, step:6999, perplexity: 29.963, speed: 28390 words
# 07:42:45 INFO:96.4%, step:7099, perplexity: 29.957, speed: 28398 words
# 07:42:46 INFO:97.8%, step:7199, perplexity: 29.951, speed: 28404 words
# 07:42:47 INFO:99.1%, step:7299, perplexity: 29.944, speed: 28407 words
# 07:42:48 INFO:Perplexity: 29.380, speed: 28404 words per sec
# 07:42:49 INFO:Latest model saved in demo_model/save_model/model-368150
#
# 07:42:49 INFO:Evaluate on validation set
# 07:42:49 INFO:epoch_size: 409
# 07:42:49 INFO:data_size: 20
# 07:42:49 INFO:num_unrollings: 20
# 07:42:49 INFO:batch_size: 20
# 07:42:49 INFO:24.4%, step:99, perplexity: 60.407, speed: 69050 words
# 07:42:50 INFO:48.9%, step:199, perplexity: 60.957, speed: 70806 words
# 07:42:50 INFO:73.3%, step:299, perplexity: 60.974, speed: 71703 words
# 07:42:51 INFO:97.8%, step:399, perplexity: 60.898, speed: 72171 words
# 07:42:51 INFO:Perplexity: 60.459, speed: 72156 words per sec
# 07:42:51 INFO:Best model is saved in demo_model/best_model/model-368150
# 07:42:51 INFO:Best validation ppl is 60.459316
#
# 07:42:51 INFO:Latest model is saved in demo_model/save_model/model-368150
# 07:42:51 INFO:Best model is saved in demo_model/best_model/model-368150
# 07:42:51 INFO:Best validation ppl is 60.459316
#
# 07:42:51 INFO:Evaluate the best model on test set
# 07:42:51 INFO:epoch_size: 409
# 07:42:51 INFO:data_size: 20
# 07:42:51 INFO:num_unrollings: 20
# 07:42:51 INFO:batch_size: 20
# 07:42:52 INFO:24.4%, step:99, perplexity: 49.483, speed: 69891 words
# 07:42:53 INFO:48.9%, step:199, perplexity: 50.715, speed: 70805 words
# 07:42:53 INFO:73.3%, step:299, perplexity: 51.050, speed: 71375 words
# 07:42:54 INFO:97.8%, step:399, perplexity: 50.983, speed: 72183 words
# 07:42:54 INFO:Perplexity: 49.935, speed: 72229 words per sec

# %%
args = config_sample('--init_dir demo_model --length 100 --start_text 之后')
vars(args)
# Out:
# {'init_dir': 'demo_model',
#  'length': 100,
#  'max_prob': False,
#  'seed': -1,
#  'start_text': '之后'}

# %%
logging.basicConfig(stream=sys.stdout,
                    format='%(asctime)s %(levelname)s:%(message)s', 
                    level=logging.INFO, datefmt='%I:%M:%S')

# Prepare parameters.
with open(os.path.join(args.init_dir, 'result.json'), 'r') as f:
    result = json.load(f)
params = result['params']
best_model = result['best_model']
best_valid_ppl = result['best_valid_ppl']
if 'encoding' in result:
    args.encoding = result['encoding']
else:
    args.encoding = 'utf-8'

args.vocab_file = os.path.join(args.init_dir, 'vocab.json')
vocab_loader = VocabularyLoader()
vocab_loader.load_vocab(args.vocab_file, args.encoding)

logging.info('best_model: %s\n', best_model)

# Create graphs
graph = tf.Graph()
with graph.as_default():
    with tf.name_scope('evaluation'):
        model = CharRNNLM(is_training=False, infer=True, **params)
    saver = tf.train.Saver(name='model_saver')

if args.seed >= 0:
    np.random.seed(args.seed)
with tf.Session(graph=graph) as session:
    saver.restore(session, best_model)
    sample = model.sample_seq(session, args.length, args.start_text, vocab_loader,
                              max_prob=args.max_prob)
    print('Sampled text is:\n\n%s' % sample)
# Out:
# 12:32:34 INFO:best_model: demo_model/best_model/model-368150
#
# Sampled text is:
#
# 之后，她被处理再次抓住这个白痴，才让自己留在这里，骑者一口每一死很悲，自由贸易城邦弥林。必须拿他的牢房，席恩紧随弯曲的真相。“三年之后，你召我去招的话，对兰尼斯特家可不起，都是一支会像白痴的钢铁是令爱……
